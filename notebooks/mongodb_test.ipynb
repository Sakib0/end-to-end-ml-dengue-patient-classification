# %%
import pandas as pd

# %%
df=pd.read_csv("dataset.csv")

# %%
df.sample(5)
# Out:
#     Gender  Age  NS1  IgG  IgM           Area     AreaType HouseType District  \
# 669   Male   17    0    0    1     New Market    Developed   Tinshed    Dhaka
# 56    Male   28    0    0    0       Gendaria  Undeveloped     Other    Dhaka
# 391   Male   38    0    0    0       Banasree    Developed   Tinshed    Dhaka
# 470   Male   11    0    0    1  Kamrangirchar  Undeveloped     Other    Dhaka
# 592   Male   44    1    1    0      Kalabagan  Undeveloped     Other    Dhaka
#
#      Outcome
# 669        0
# 56         0
# 391        0
# 470        0
# 592        1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Gender     1000 non-null   object
#  1   Age        1000 non-null   int64
#  2   NS1        1000 non-null   int64
#  3   IgG        1000 non-null   int64
#  4   IgM        1000 non-null   int64
#  5   Area       1000 non-null   object
#  6   AreaType   1000 non-null   object
#  7   HouseType  1000 non-null   object
#  8   District   1000 non-null   object
#  9   Outcome    1000 non-null   int64
# dtypes: int64(5), object(5)
# memory usage: 78.3+ KB

# %%
df.isnull().sum()
# Out:
# Gender       0
# Age          0
# NS1          0
# IgG          0
# IgM          0
# Area         0
# AreaType     0
# HouseType    0
# District     0
# Outcome      0
# dtype: int64

# %%
data=df.to_dict(orient="records")

# %%
data
# Out:
# [{'Gender': 'Female',
#   'Age': 45,
#   'NS1': 0,
#   'IgG': 0,
#   'IgM': 0,
#   'Area': 'Mirpur',
#   'AreaType': 'Undeveloped',
#   'HouseType': 'Building',
#   'District': 'Dhaka',
#   'Outcome': 0},
#  {'Gender': 'Male',
#   'Age': 17,
#   'NS1': 0,
#   'IgG': 0,
#   'IgM': 1,
#   'Area': 'Chawkbazar',
#   'AreaType': 'Developed',
#   'HouseType': 'Building',
#   'District': 'Dhaka',
#   'Outcome': 0},
#  {'Gender': 'Female',
#   'Age': 29,
#   'NS1': 0,
#   'IgG': 0,
#   'IgM': 0,
#   'Area': 'Paltan',
#   'AreaType': 'Undeveloped',
#   'HouseType': 'Other',
#   'District': 'Dhaka',
#   'Outcome': 0},
#  {'Gender': 'Female',
#   'Age': 63,
#   'NS1': 1,
#   'IgG': 1,
#   'IgM': 0,
#   'Area': 'Motijheel',
#   'AreaType': 'Developed',
#   'HouseType': 'Other',
#   'District': 'Dhaka',
#   'Outcome': 1},
#  {'Gender': 'Male',
#   'Age': 22,
#   'NS1': 0,
#   'IgG': 0,
#   'IgM': 0,
#   'Area': 'Gendaria',
#   'AreaType': 'Undeveloped',
#   'HouseType': 'Building',
#   'District': 'Dhaka',
#   'Outcome': 0},
#  {'Gender': 'Female',
#   'Age': 36,
#   'NS1': 0,
#   'IgG': 0,
#   'IgM': 1,
#   'Area': 'Dhanmondi',
#   'AreaType': 'Developed',
#   'HouseType': 'Other',
#   'District': 'Dhaka',
#   'Outcome': 0},
#  {'Gender': 'Female',
#   'Age': 15,
#   'NS1': 0,
#   'IgG': 0,
#   'IgM': 1,
#   'Area': 'New Market',
#   'AreaType': 'Undeveloped',
#   'HouseType': 'Building',
#   'District': 'Dhaka',
#   'Outcome': 0},
#  {'Gender': 'Male',
#   'Age': 26,
#   'NS1': 0,
#   'IgG': 0,
#   'IgM': 0,
#   'Area': 'New Market',
#   'AreaType': 'Developed',
#   'HouseType': 'Other',
#   'District': 'Dhaka',
#   'Outcome': 0},
#  {'Gender': 'Female',
#   'Age': 31,
#   'NS1': 0,
#   'IgG': 0,
#   'IgM': 1,
#   'Area': 'Dhanmondi',
#   'AreaType': 'Undeveloped',
#   'HouseType': 'Tinshed',
#   'District': 'Dhaka',
#   'Outcome': 0},
#  {'Gender': 'Female',
#   'Age': 10,
#   'NS1': 0,
#   'IgG': 0,
#   'IgM': 1,
#   'Area': 'Sher-e-Bangla Nagar',
#   'AreaType': 'Developed',
#   'HouseType': 'Tinshed',
#   'District': 'Dhaka',
#   'Outcome': 0},
#  {'Gender': 'Female',
#   'Age': 31,
#   'NS1': 1,
#   'IgG': 1,
#   'IgM': 0,
#   'Area': 'Kafrul',
#   'AreaType': 'Undeveloped',
#   'HouseType': 'Building',
#   'District': 'Dhaka',
#   'Outcome': 1},
#  {'Gender': 'Male',
#   'Age': 10,
#   'NS1': 0,
#   'IgG': 0,
#   'IgM': 0,
#   'Area': 'Dhanmondi',
#   'AreaType': 'Developed',
#   'HouseType': 'Tinshed',
#   'District': 'Dhaka',
#   'Outcome': 0},
#  {'Gender': 'Female',
#   'Age': 13,
#   'NS1': 1,
#   'IgG': 1,
#   'IgM': 0,
#   'Area': 'Pallabi',
#   'AreaType': 'Undeveloped',
#   'HouseType': 'Building',
#   'District': 'Dhaka',
#   'Outcome': 1},
#  {'Gender': 'Female',
#   'Age': 43,
#   'NS1': 1,
#   'IgG': 1,
#   'IgM': 0,
#   'Area': 'Mohammadpur',
#   'AreaType': 'Developed',
#   'HouseType': 'Building',
#   'District': 'Dhaka',
#   'Outcome': 1},
#  {'Gender': 'Male',
#   'Age': 52,
#   'NS1': 0,
#   'IgG': 0,
#   'IgM': 0,
#   'Area': 'Shahbagh',
#   'AreaType': 'Undeveloped',
#   'HouseType': 'Other',
#   'District': 'Dhaka',
#   'Outcome': 0},
#  {'Gender': 'Female',
#   'Age': 12,
#   'NS1': 1,
#   'IgG': 1,
#   'IgM': 1,
#   'Area': 'Shyampur',
#   'AreaType': 'Developed',
#   'HouseType': 'Tinshed',
#   'District': 'Dhaka',
#   'Outcome': 1},
#  {'Gender': 'Male',
#   'Age': 18,
#   'NS1': 0,
#   'IgG': 0,
#   'IgM': 1,
#   'Area': 'Kalabagan',
#   'AreaType': 'Undeveloped',
#   'HouseType': 'Tinshed',
#   'District': 'Dhaka',
#   'Outcome': 0},
#  {'Gender': 'Male',
#   'Age': 56,
#   'NS1': 0,
#   'IgG': 0,
#   'IgM': 1,
#   'Area': 'Bosila',
#   'AreaType': 'Developed',
#   'HouseType': 'Building',
#   'District': 'Dhaka',
#   'Outcome': 0},
#  {'Gender': 'Male',
#   'Age': 9,
#   'NS1': 1,
#   'IgG': 1,
#   'IgM': 1,
#   'Area': 'Mirpur',
#   'AreaType': 'Undeveloped',
#   'HouseType': 'Tinshed',
#   'District': 'Dhaka',
#   'Outcome': 1},
#  {'Gender': 'Male',
#   'Age': 27,
#   'NS1': 1,
#   'IgG': 1,
#   'IgM': 0,
#   'Area': 'Mirpur',
#   'AreaType': 'Developed',
#   'HouseType': 'Tinshed',
#   'District': 'Dhaka',
#   'Outcome': 1},
#  {'Gender': 'Female',
#   'Age': 31,
#   'NS1': 0,
#   'IgG': 1,
#   'IgM': 0,
#   'Area': 'Jatrabari',
#   'AreaType': 'Undeveloped',
#   'HouseType': 'Tinshed',
#   'District': 'Dhaka',
#   'Outcome': 1},
#  {'Gender': 'Female',
#   'Age': 23,
#   'NS1': 0,
#   'IgG': 0,
#   'IgM': 0,
#   'Area': 'Adabor',
#   'AreaType': 'Developed',
#   'HouseType': 'Other',
#   'District': 'Dhaka',
#   'Outcome': 0},
#  {'Gender': 'Female',
#   'Age': 37,
#   'NS1': 0,
#   'IgG': 0,
#   'IgM': 1,
#   'Area': 'Kamrangirchar',
#   'AreaType': 'Undeveloped',
#   'HouseType': 'Tinshed',
#   'District': 'Dhaka',
#   'Outcome': 0},
#  {'Gender': 'Male',
#   'Age': 44,
#   'NS1': 0,
#   'IgG': 0,
#   'IgM': 1,
#   'Area': 'Biman Bandar',
#   'AreaType': 'Developed',
#   'HouseType': 'Other',
#   'District': 'Dhaka',
#   'Outcome': 0},
#  {'Gender': 'Female',
#   'Age': 17,
#   'NS1': 1,
#   'IgG': 1,
#   'IgM': 0,
#   'Area': 'Pallabi',
#   'AreaType': 'Undeveloped',
#   'HouseType': 'Building',
#   'District': 'Dhaka',
#   'Outcome': 1},
#  {'Gender': 'Female',
#   'Age': 64,
#   'NS1': 1,
#   'IgG': 1,
#   'IgM': 1,
#   'Area': 'Jatrabari',
#   'AreaType': 'Developed',
#   'HouseType': 'Other',
#   'District': 'Dhaka',
#   'Outcome': 1},
#  {'Gender': 'Female',
#   'Age': 65,
#   'NS1': 0,
#   'IgG': 0,
#   'IgM': 0,
#   'Area': 'Gendaria',
#   'AreaType': 'Undeveloped',
#   'HouseType': 'Tinshed',
#   'District': 'Dhaka',
#   'Outcome': 0},
#  {'Gender': 'Female',
#   'Age': 60,
#   'NS1': 0,
#   'IgG': 0,
#   'IgM': 0,
#   'Area': 'Pallabi',
#   'AreaType': 'Developed',
#   'HouseType': 'Other',
#   'District': 'Dhaka',
#   'Outcome': 0},
#  {'Gender': 'Female',
#   'Age': 44,
#   'NS1': 1,
#   'IgG': 1,
#   'IgM': 1,
#   'Area': 'Kafrul',
#   'AreaType': 'Undeveloped',
#   'HouseType': 'Tinshed',
#   'District': 'Dhaka',
#   'Outcome': 1},
#  {'Gender': 'Female',
#   'Age': 13,
#   'NS1': 0,
#   'IgG': 1,
#   'IgM': 0,
#   'Area': 'Mohammadpur',
#   'AreaType': 'Developed',
#   'HouseType': 'Building',
#   'District': 'Dhaka',
#   'Outcome': 1},
#  {'Gender': 'Female',
#   'Age': 35,
#   'NS1': 0,
#   'IgG': 0,
#   'IgM': 0,
#   'Area': 'Ramna',
#   'AreaType': 'Undeveloped',
#   'HouseType': 'Building',
#   'District': 'Dhaka',
#   'Outcome': 0},
#  {'Gender': 'Male',
#   'Age': 13,
#   'NS1': 1,
#   'IgG': 1,
#   'IgM': 1,
#   'Area': 'Jatrabari',
#   'AreaType': 'Developed',
#   'HouseType': 'Tinshed',
#   'District': 'Dhaka',
#   'Outcome': 1},
#  {'Gender': 'Female',
#   'Age': 39,
#   'NS1': 0,
#   'IgG': 0,
#   'IgM': 1,
#   'Area': 'Badda',
#   'AreaType': 'Undeveloped',
#   'HouseType': 'Building',
#   'District': 'Dhaka',
#   'Outcome': 0},
#  {'Gender': 'Female',
#   'Age': 27,
#   'NS1': 0,
#   'IgG': 0,
#   'IgM': 1,
#   'Area': 'Bangshal',
#   'AreaType': 'Developed',
#   'HouseType': 'Other',
#   'District': 'Dhaka',
#   'Outcome': 0},
#  {'Gender': 'Male',
#   'Age': 11,
#   'NS1': 1,
#   'IgG': 1,
#   'IgM': 1,
#   'Area': 'Sabujbagh',
#   'AreaType': 'Undeveloped',
#   'HouseType': 'Tinshed',
#   'District': 'Dhaka',
#   'Outcome': 1},
#  {'Gender': 'Female',
#   'Age': 46,
#   'NS1': 1,
#   'IgG': 1,
#   'IgM': 1,
#   'Area': 'Ramna',
#   'AreaType': 'Developed',
#   'HouseType': 'Other',
#   'District': 'Dhaka',
#   'Outcome': 1},
#  {'Gender': 'Male',
#   'Age': 10,
#   'NS1': 1,
#   'IgG': 1,
#   'IgM': 0,
#   'Area': 'Hazaribagh',
#   'AreaType': 'Undeveloped',
#   'HouseType': 'Tinshed',
#   'District': 'Dhaka',
#   'Outcome': 1},
#  {'Gender': 'Female',
#   'Age': 13,
#   'NS1': 0,
#   'IgG': 0,
#   'IgM': 1,
#   'Area': 'Sutrapur',
#   'AreaType': 'Developed',
#   'HouseType': 'Building',
#   'District': 'Dhaka',
#   'Outcome': 0},
#  {'Gender': 'Male',
#   'Age': 50,
#   'NS1': 0,
#   'IgG': 1,
#   'IgM': 0,
#   'Area': 'Sabujbagh',
#   'AreaType': 'Undeveloped',
#   'HouseType': 'Other',
#   'District': 'Dhaka',
#   'Outcome': 1},
#  {'Gender': 'Male',
#   'Age': 34,
#   'NS1': 1,
#   'IgG': 1,
#   'IgM': 0,
#   'Area': 'Mirpur',
#   'AreaType': 'Developed',
#   'HouseType': 'Other',
#   'District': 'Dhaka',
#   'Outcome': 1},
#  {'Gender': 'Female',
#   'Age': 54,
#   'NS1': 0,
#   'IgG': 0,
#   'IgM': 1,
#   'Area': 'Kalabagan',
#   'AreaType': 'Undeveloped',
#   'HouseType': 'Tinshed',
#   'District': 'Dhaka',
#   'Outcome': 0},
#  {'Gender': 'Female',
#   'Age': 16,
#   'NS1': 0,
#   'IgG': 0,
#   'IgM': 1,
#   'Area': 'Ramna',
#   'AreaType': 'Developed',
#   'HouseType': 'Other',
#   'District': 'Dhaka',
#   'Outcome': 0},
#  {'Gender': 'Male',
#   'Age': 51,
#   'NS1': 1,
#   'IgG': 1,
#   'IgM': 0,
#   'Area': 'Bangshal',
#   'AreaType': 'Undeveloped',
#   'HouseType': 'Tinshed',
#   'District': 'Dhaka',
#   'Outcome': 1},
#  {'Gender': 'Female',
#   'Age': 9,
#   'NS1': 1,
#   'IgG': 1,
#   'IgM': 1,
#   'Area': 'Lalbagh',
#   'AreaType': 'Developed',
#   'HouseType': 'Tinshed',
#   'District': 'Dhaka',
#   'Outcome': 1},
#  {'Gender': 'Female',
#   'Age': 37,
#   'NS1': 0,
#   'IgG': 0,
#   'IgM': 0,
#   'Area': 'Demra',
#   'AreaType': 'Undeveloped',
#   'HouseType': 'Building',
#   'District': 'Dhaka',
#   'Outcome': 0},
#  {'Gender': 'Female',
#   'Age': 13,
#   'NS1': 0,
#   'IgG': 0,
#   'IgM': 0,
#   'Area': 'Banasree',
#   'AreaType': 'Developed',
#   'HouseType': 'Tinshed',
#   'District': 'Dhaka',
#   'Outcome': 0},
#  {'Gender': 'Male',
#   'Age': 62,
#   'NS1': 0,
#   'IgG': 1,
#   'IgM': 0,
#   'Area': 'Sabujbagh',
#   'AreaType': 'Undeveloped',
#   'HouseType': 'Tinshed',
#   'District': 'Dhaka',
#   'Outcome': 1},
#  {'Gender': 'Male',
#   'Age': 17,
#   'NS1': 0,
#   'IgG': 0,
#   'IgM': 1,
#   'Area': 'Ramna',
#   'AreaType': 'Developed',
#   'HouseType': 'Building',
#   'District': 'Dhaka',
#   'Outcome': 0},
#  {'Gender': 'Female',
#   'Age': 35,
#   'NS1': 0,
#   'IgG': 0,
#   'IgM': 1,
#   'Area': 'Bosila',
#   'AreaType': 'Undeveloped',
#   'HouseType': 'Tinshed',
#   'District': 'Dhaka',
#   'Outcome': 0},
#  {'Gender': 'Male',
#   'Age': 9,
#   'NS1': 1,
#   'IgG': 1,
#   'IgM': 0,
#   'Area': 'Cantonment',
#   'AreaType': 'Developed',
#   'HouseType': 'Tinshed',
#   'District': 'Dhaka',
#   'Outcome': 1},
#  {'Gender': 'Male',
#   'Age': 14,
#   'NS1': 1,
#   'IgG': 1,
#   'IgM': 0,
#   'Area': 'Jatrabari',
#   'AreaType': 'Undeveloped',
#   'HouseType': 'Tinshed',
#   'District': 'Dhaka',
#   'Outcome': 1},
#  {'Gender': 'Male',
#   'Age': 37,
#   'NS1': 0,
#   'IgG': 0,
#   'IgM': 0,
#   'Area': 'Kalabagan',
#   'AreaType': 'Developed',
#   'HouseType': 'Tinshed',
#   'District': 'Dhaka',
#   'Outcome': 0},
#  {'Gender': 'Male',
#   'Age': 13,
#   'NS1': 0,
#   'IgG': 0,
#   'IgM': 0,
#   'Area': 'Keraniganj',
#   'AreaType': 'Undeveloped',
#   'HouseType': 'Other',
#   'District': 'Dhaka',
#   'Outcome': 0},
#  {'Gender': 'Male',
#   'Age': 57,
#   'NS1': 0,
#   'IgG': 0,
#   'IgM': 0,
#   'Area': 'Shyampur',
#   'AreaType': 'Developed',
#   'HouseType': 'Building',
#   'District': 'Dhaka',
#   'Outcome': 0},
#  {'Gender': 'Female',
#   'Age': 41,
#   'NS1': 0,
#   'IgG': 0,
#   'IgM': 0,
#   'Area': 'Motijheel',
#   'AreaType': 'Undeveloped',
#   'HouseType': 'Building',
#   'District': 'Dhaka',
#   'Outcome': 0},
#  {'Gender': 'Male',
#   'Age': 24,
#   'NS1': 1,
#   'IgG': 1,
#   'IgM': 1,
#   'Area': 'Bosila',
#   'AreaType': 'Developed',
#   'HouseType': 'Building',
#   'District': 'Dhaka',
#   'Outcome': 1},
#  {'Gender': 'Male',
#   'Age': 28,
#   'NS1': 0,
#   'IgG': 0,
#   'IgM': 0,
#   'Area': 'Gendaria',
#   'AreaType': 'Undeveloped',
#   'HouseType': 'Other',
#   'District': 'Dhaka',
#   'Outcome': 0},
#  {'Gender': 'Male',
#   'Age': 25,
#   'NS1': 0,
#   'IgG': 0,
#   'IgM': 1,
#   'Area': 'Pallabi',
#   'AreaType': 'Developed',
#   'HouseType': 'Other',
#   'District': 'Dhaka',
#   'Outcome': 0},
#  {'Gender': 'Male',
#   'Age': 44,
#   'NS1': 0,
#   'IgG': 0,
#   'IgM': 1,
#   'Area': 'Sutrapur',
#   'AreaType': 'Undeveloped',
#   'HouseType': 'Tinshed',
#   'District': 'Dhaka',
#   'Outcome': 0},
#  {'Gender': 'Male',
#   'Age': 10,
#   'NS1': 1,
#   'IgG': 1,
#   'IgM': 1,
#   'Area': 'Bangshal',
#   'AreaType': 'Developed',
#   'HouseType': 'Tinshed',
#   'District': 'Dhaka',
#   'Outcome': 1},
#  {'Gender': 'Female',
#   'Age': 13,
#   'NS1': 1,
#   'IgG': 1,
#   'IgM': 1,
#   'Area': 'Dhanmondi',
#   'AreaType': 'Undeveloped',
#   'HouseType': 'Other',
#   'District': 'Dhaka',
#   'Outcome': 1},
#  {'Gender': 'Female',
#   'Age': 65,
#   'NS1': 1,
#   'IgG': 1,
#   'IgM': 0,
#   'Area': 'Tejgaon',
#   'AreaType': 'Developed',
#   'HouseType': 'Building',
#   'District': 'Dhaka',
#   'Outcome': 1},
#  {'Gender': 'Male',
#   'Age': 53,
#   'NS1': 0,
#   'IgG': 0,
#   'IgM': 0,
#   'Area': 'Badda',
#   'AreaType': 'Undeveloped',
#   'HouseType': 'Other',
#   'District': 'Dhaka',
#   'Outcome': 0},
#  {'Gender': 'Male',
#   'Age': 54,
#   'NS1': 0,
#   'IgG': 0,
#   'IgM': 1,
#   'Area': 'Demra',
#   'AreaType': 'Developed',
#   'HouseType': 'Other',
#   'District': 'Dhaka',
#   'Outcome': 0},
#  {'Gender': 'Female',
#   'Age': 59,
#   'NS1': 0,
#   'IgG': 0,
#   'IgM': 1,
#   'Area': 'Khilkhet',
#   'AreaType': 'Undeveloped',
#   'HouseType': 'Building',
#   'District': 'Dhaka',
#   'Outcome': 0},
#  {'Gender': 'Male',
#   'Age': 47,
#   'NS1': 1,
#   'IgG': 1,
#   'IgM': 1,
#   'Area': 'Kadamtali',
#   'AreaType': 'Developed',
#   'HouseType': 'Building',
#   'District': 'Dhaka',
#   'Outcome': 1},
#  {'Gender': 'Female',
#   'Age': 28,
#   'NS1': 1,
#   'IgG': 1,
#   'IgM': 1,
#   'Area': 'Bangshal',
#   'AreaType': 'Undeveloped',
#   'HouseType': 'Other',
#   'District': 'Dhaka',
#   'Outcome': 1},
#  {'Gender': 'Female',
#   'Age': 38,
#   'NS1': 1,
#   'IgG': 1,
#   'IgM': 0,
#   'Area': 'Kadamtali',
#   'AreaType': 'Developed',
#   'HouseType': 'Tinshed',
#   'District': 'Dhaka',
#   'Outcome': 1},
#  {'Gender': 'Female',
#   'Age': 11,
#   'NS1': 1,
#   'IgG': 1,
#   'IgM': 0,
#   'Area': 'Kafrul',
#   'AreaType': 'Undeveloped',
#   'HouseType': 'Tinshed',
#   'District': 'Dhaka',
#   'Outcome': 1},
#  {'Gender': 'Female',
#   'Age': 65,
#   'NS1': 0,
#   'IgG': 0,
#   'IgM': 0,
#   'Area': 'Shahbagh',
#   'AreaType': 'Developed',
#   'HouseType': 'Tinshed',
#   'District': 'Dhaka',
#   'Outcome': 0},
#  {'Gender': 'Male',
#   'Age': 17,
#   'NS1': 1,
#   'IgG': 1,
#   'IgM': 0,
#   'Area': 'Motijheel',
#   'AreaType': 'Undeveloped',
#   'HouseType': 'Other',
#   'District': 'Dhaka',
#   'Outcome': 1},
#  {'Gender': 'Male',
#   'Age': 64,
#   'NS1': 0,
#   'IgG': 0,
#   'IgM': 0,
#   'Area': 'Gulshan',
#   'AreaType': 'Developed',
#   'HouseType': 'Tinshed',
#   'District': 'Dhaka',
#   'Outcome': 0},
#  {'Gender': 'Female',
#   'Age': 45,
#   'NS1': 1,
#   'IgG': 1,
#   'IgM': 1,
#   'Area': 'Kamrangirchar',
#   'AreaType': 'Undeveloped',
#   'HouseType': 'Tinshed',
#   'District': 'Dhaka',
#   'Outcome': 1},
#  {'Gender': 'Female',
#   'Age': 10,
#   'NS1': 1,
#   'IgG': 1,
#   'IgM': 0,
#   'Area': 'Khilkhet',
#   'AreaType': 'Developed',
#   'HouseType': 'Building',
#   'District': 'Dhaka',
#   'Outcome': 1},
#  {'Gender': 'Male',
#   'Age': 49,
#   'NS1': 1,
#   'IgG': 1,
#   'IgM': 1,
#   'Area': 'Demra',
#   'AreaType': 'Undeveloped',
#   'HouseType': 'Other',
#   'District': 'Dhaka',
#   'Outcome': 1},
#  {'Gender': 'Male',
#   'Age': 61,
#   'NS1': 0,
#   'IgG': 0,
#   'IgM': 1,
#   'Area': 'Ramna',
#   'AreaType': 'Developed',
#   'HouseType': 'Tinshed',
#   'District': 'Dhaka',
#   'Outcome': 0},
#  {'Gender': 'Female',
#   'Age': 61,
#   'NS1': 1,
#   'IgG': 1,
#   'IgM': 1,
#   'Area': 'Bangshal',
#   'AreaType': 'Undeveloped',
#   'HouseType': 'Other',
#   'District': 'Dhaka',
#   'Outcome': 1},
#  {'Gender': 'Male',
#   'Age': 21,
#   'NS1': 0,
#   'IgG': 0,
#   'IgM': 1,
#   'Area': 'Dhanmondi',
#   'AreaType': 'Developed',
#   'HouseType': 'Building',
#   'District': 'Dhaka',
#   'Outcome': 0},
#  {'Gender': 'Male',
#   'Age': 64,
#   'NS1': 1,
#   'IgG': 1,
#   'IgM': 1,
#   'Area': 'Jatrabari',
#   'AreaType': 'Undeveloped',
#   'HouseType': 'Other',
#   'District': 'Dhaka',
#   'Outcome': 1},
#  {'Gender': 'Female',
#   'Age': 24,
#   'NS1': 0,
#   'IgG': 0,
#   'IgM': 0,
#   'Area': 'Bosila',
#   'AreaType': 'Developed',
#   'HouseType': 'Tinshed',
#   'District': 'Dhaka',
#   'Outcome': 0},
#  {'Gender': 'Female',
#   'Age': 62,
#   'NS1': 1,
#   'IgG': 1,
#   'IgM': 0,
#   'Area': 'Bosila',
#   'AreaType': 'Undeveloped',
#   'HouseType': 'Building',
#   'District': 'Dhaka',
#   'Outcome': 1},
#  {'Gender': 'Male',
#   'Age': 59,
#   'NS1': 1,
#   'IgG': 1,
#   'IgM': 1,
#   'Area': 'Shahbagh',
#   'AreaType': 'Developed',
#   'HouseType': 'Other',
#   'District': 'Dhaka',
#   'Outcome': 1},
#  {'Gender': 'Male',
#   'Age': 44,
#   'NS1': 0,
#   'IgG': 0,
#   'IgM': 0,
#   'Area': 'New Market',
#   'AreaType': 'Undeveloped',
#   'HouseType': 'Tinshed',
#   'District': 'Dhaka',
#   'Outcome': 0},
#  {'Gender': 'Female',
#   'Age': 12,
#   'NS1': 1,
#   'IgG': 1,
#   'IgM': 0,
#   'Area': 'Tejgaon',
#   'AreaType': 'Developed',
#   'HouseType': 'Other',
#   'District': 'Dhaka',
#   'Outcome': 1},
#  {'Gender': 'Female',
#   'Age': 29,
#   'NS1': 1,
#   'IgG': 1,
#   'IgM': 1,
#   'Area': 'Kalabagan',
#   'AreaType': 'Undeveloped',
#   'HouseType': 'Tinshed',
#   'District': 'Dhaka',
#   'Outcome': 1},
#  {'Gender': 'Male',
#   'Age': 38,
#   'NS1': 0,
#   'IgG': 0,
#   'IgM': 0,
#   'Area': 'Biman Bandar',
#   'AreaType': 'Developed',
#   'HouseType': 'Building',
#   'District': 'Dhaka',
#   'Outcome': 0},
#  {'Gender': 'Female',
#   'Age': 45,
#   'NS1': 1,
#   'IgG': 1,
#   'IgM': 0,
#   'Area': 'Banasree',
#   'AreaType': 'Undeveloped',
#   'HouseType': 'Building',
#   'District': 'Dhaka',
#   'Outcome': 1},
#  {'Gender': 'Female',
#   'Age': 54,
#   'NS1': 1,
#   'IgG': 1,
#   'IgM': 1,
#   'Area': 'Demra',
#   'AreaType': 'Developed',
#   'HouseType': 'Building',
#   'District': 'Dhaka',
#   'Outcome': 1},
#  {'Gender': 'Female',
#   'Age': 50,
#   'NS1': 1,
#   'IgG': 1,
#   'IgM': 1,
#   'Area': 'Keraniganj',
#   'AreaType': 'Undeveloped',
#   'HouseType': 'Tinshed',
#   'District': 'Dhaka',
#   'Outcome': 1},
#  {'Gender': 'Female',
#   'Age': 39,
#   'NS1': 1,
#   'IgG': 1,
#   'IgM': 0,
#   'Area': 'Sabujbagh',
#   'AreaType': 'Developed',
#   'HouseType': 'Building',
#   'District': 'Dhaka',
#   'Outcome': 1},
#  {'Gender': 'Female',
#   'Age': 53,
#   'NS1': 0,
#   'IgG': 0,
#   'IgM': 0,
#   'Area': 'Keraniganj',
#   'AreaType': 'Undeveloped',
#   'HouseType': 'Other',
#   'District': 'Dhaka',
#   'Outcome': 0},
#  {'Gender': 'Male',
#   'Age': 64,
#   'NS1': 1,
#   'IgG': 1,
#   'IgM': 1,
#   'Area': 'Mirpur',
#   'AreaType': 'Developed',
#   'HouseType': 'Building',
#   'District': 'Dhaka',
#   'Outcome': 1},
#  {'Gender': 'Female',
#   'Age': 60,
#   'NS1': 1,
#   'IgG': 1,
#   'IgM': 1,
#   'Area': 'Gulshan',
#   'AreaType': 'Undeveloped',
#   'HouseType': 'Other',
#   'District': 'Dhaka',
#   'Outcome': 1},
#  {'Gender': 'Female',
#   'Age': 45,
#   'NS1': 0,
#   'IgG': 0,
#   'IgM': 1,
#   'Area': 'Hazaribagh',
#   'AreaType': 'Developed',
#   'HouseType': 'Other',
#   'District': 'Dhaka',
#   'Outcome': 0},
#  {'Gender': 'Male',
#   'Age': 32,
#   'NS1': 0,
#   'IgG': 0,
#   'IgM': 0,
#   'Area': 'Banasree',
#   'AreaType': 'Undeveloped',
#   'HouseType': 'Other',
#   'District': 'Dhaka',
#   'Outcome': 0},
#  {'Gender': 'Female',
#   'Age': 26,
#   'NS1': 0,
#   'IgG': 0,
#   'IgM': 0,
#   'Area': 'Sabujbagh',
#   'AreaType': 'Developed',
#   'HouseType': 'Building',
#   'District': 'Dhaka',
#   'Outcome': 0},
#  {'Gender': 'Female',
#   'Age': 58,
#   'NS1': 1,
#   'IgG': 1,
#   'IgM': 1,
#   'Area': 'Rampura',
#   'AreaType': 'Undeveloped',
#   'HouseType': 'Building',
#   'District': 'Dhaka',
#   'Outcome': 1},
#  {'Gender': 'Female',
#   'Age': 23,
#   'NS1': 1,
#   'IgG': 1,
#   'IgM': 0,
#   'Area': 'Badda',
#   'AreaType': 'Developed',
#   'HouseType': 'Tinshed',
#   'District': 'Dhaka',
#   'Outcome': 1},
#  {'Gender': 'Male',
#   'Age': 30,
#   'NS1': 0,
#   'IgG': 0,
#   'IgM': 1,
#   'Area': 'Shahbagh',
#   'AreaType': 'Undeveloped',
#   'HouseType': 'Tinshed',
#   'District': 'Dhaka',
#   'Outcome': 0},
#  {'Gender': 'Female',
#   'Age': 62,
#   'NS1': 0,
#   'IgG': 0,
#   'IgM': 0,
#   'Area': 'Rampura',
#   'AreaType': 'Developed',
#   'HouseType': 'Tinshed',
#   'District': 'Dhaka',
#   'Outcome': 0},
#  {'Gender': 'Female',
#   'Age': 34,
#   'NS1': 0,
#   'IgG': 0,
#   'IgM': 0,
#   'Area': 'Sutrapur',
#   'AreaType': 'Undeveloped',
#   'HouseType': 'Other',
#   'District': 'Dhaka',
#   'Outcome': 0},
#  {'Gender': 'Female',
#   'Age': 58,
#   'NS1': 0,
#   'IgG': 0,
#   'IgM': 0,
#   'Area': 'Dhanmondi',
#   'AreaType': 'Developed',
#   'HouseType': 'Other',
#   'District': 'Dhaka',
#   'Outcome': 0},
#  {'Gender': 'Female',
#   'Age': 51,
#   'NS1': 0,
#   'IgG': 0,
#   'IgM': 1,
#   'Area': 'Shyampur',
#   'AreaType': 'Undeveloped',
#   'HouseType': 'Building',
#   'District': 'Dhaka',
#   'Outcome': 0},
#  {'Gender': 'Female',
#   'Age': 50,
#   'NS1': 1,
#   'IgG': 1,
#   'IgM': 0,
#   'Area': 'Bangshal',
#   'AreaType': 'Developed',
#   'HouseType': 'Tinshed',
#   'District': 'Dhaka',
#   'Outcome': 1},
#  {'Gender': 'Female',
#   'Age': 9,
#   'NS1': 0,
#   'IgG': 0,
#   'IgM': 0,
#   'Area': 'Chawkbazar',
#   'AreaType': 'Undeveloped',
#   'HouseType': 'Tinshed',
#   'District': 'Dhaka',
#   'Outcome': 0},
#  {'Gender': 'Female',
#   'Age': 8,
#   'NS1': 0,
#   'IgG': 0,
#   'IgM': 1,
#   'Area': 'Khilkhet',
#   'AreaType': 'Developed',
#   'HouseType': 'Other',
#   'District': 'Dhaka',
#   'Outcome': 0},
#  {'Gender': 'Male',
#   'Age': 45,
#   'NS1': 1,
#   'IgG': 1,
#   'IgM': 1,
#   'Area': 'Jatrabari',
#   'AreaType': 'Undeveloped',
#   'HouseType': 'Building',
#   'District': 'Dhaka',
#   'Outcome': 1},
#  {'Gender': 'Male',
#   'Age': 27,
#   'NS1': 1,
#   'IgG': 1,
#   'IgM': 1,
#   'Area': 'Kafrul',
#   'AreaType': 'Developed',
#   'HouseType': 'Other',
#   'District': 'Dhaka',
#   'Outcome': 1},
#  {'Gender': 'Female',
#   'Age': 31,
#   'NS1': 1,
#   'IgG': 1,
#   'IgM': 1,
#   'Area': 'Demra',
#   'AreaType': 'Undeveloped',
#   'HouseType': 'Building',
#   'District': 'Dhaka',
#   'Outcome': 1},
#  {'Gender': 'Female',
#   'Age': 44,
#   'NS1': 0,
#   'IgG': 0,
#   'IgM': 0,
#   'Area': 'Gendaria',
#   'AreaType': 'Developed',
#   'HouseType': 'Other',
#   'District': 'Dhaka',
#   'Outcome': 0},
#  {'Gender': 'Female',
#   'Age': 39,
#   'NS1': 1,
#   'IgG': 1,
#   'IgM': 0,
#   'Area': 'Tejgaon',
#   'AreaType': 'Undeveloped',
#   'HouseType': 'Tinshed',
#   'District': 'Dhaka',
#   'Outcome': 1},
#  {'Gender': 'Female',
#   'Age': 9,
#   'NS1': 1,
#   'IgG': 1,
#   'IgM': 0,
#   'Area': 'Khilgaon',
#   'AreaType': 'Developed',
#   'HouseType': 'Tinshed',
#   'District': 'Dhaka',
#   'Outcome': 1},
#  {'Gender': 'Male',
#   'Age': 51,
#   'NS1': 1,
#   'IgG': 1,
#   'IgM': 0,
#   'Area': 'Badda',
#   'AreaType': 'Undeveloped',
#   'HouseType': 'Other',
#   'District': 'Dhaka',
#   'Outcome': 1},
#  {'Gender': 'Male',
#   'Age': 24,
#   'NS1': 0,
#   'IgG': 0,
#   'IgM': 0,
#   'Area': 'Gendaria',
#   'AreaType': 'Developed',
#   'HouseType': 'Other',
#   'District': 'Dhaka',
#   'Outcome': 0},
#  {'Gender': 'Male',
#   'Age': 46,
#   'NS1': 1,
#   'IgG': 1,
#   'IgM': 0,
#   'Area': 'Bangshal',
#   'AreaType': 'Undeveloped',
#   'HouseType': 'Tinshed',
#   'District': 'Dhaka',
#   'Outcome': 1},
#  {'Gender': 'Male',
#   'Age': 39,
#   'NS1': 1,
#   'IgG': 1,
#   'IgM': 0,
#   'Area': 'Paltan',
#   'AreaType': 'Developed',
#   'HouseType': 'Building',
#   'District': 'Dhaka',
#   'Outcome': 1},
#  {'Gender': 'Female',
#   'Age': 14,
#   'NS1': 1,
#   'IgG': 1,
#   'IgM': 0,
#   'Area': 'Kamrangirchar',
#   'AreaType': 'Undeveloped',
#   'HouseType': 'Building',
#   'District': 'Dhaka',
#   'Outcome': 1},
#  {'Gender': 'Male',
#   'Age': 42,
#   'NS1': 1,
#   'IgG': 1,
#   'IgM': 0,
#   'Area': 'Khilgaon',
#   'AreaType': 'Developed',
#   'HouseType': 'Other',
#   'District': 'Dhaka',
#   'Outcome': 1},
#  {'Gender': 'Male',
#   'Age': 37,
#   'NS1': 1,
#   'IgG': 1,
#   'IgM': 0,
#   'Area': 'Jatrabari',
#   'AreaType': 'Undeveloped',
#   'HouseType': 'Tinshed',
#   'District': 'Dhaka',
#   'Outcome': 1},
#  {'Gender': 'Male',
#   'Age': 31,
#   'NS1': 1,
#   'IgG': 1,
#   'IgM': 0,
#   'Area': 'Adabor',
#   'AreaType': 'Developed',
#   'HouseType': 'Building',
#   'District': 'Dhaka',
#   'Outcome': 1},
#  {'Gender': 'Male',
#   'Age': 57,
#   'NS1': 0,
#   'IgG': 0,
#   'IgM': 0,
#   'Area': 'Bosila',
#   'AreaType': 'Undeveloped',
#   'HouseType': 'Tinshed',
#   'District': 'Dhaka',
#   'Outcome': 0},
#  {'Gender': 'Female',
#   'Age': 30,
#   'NS1': 0,
#   'IgG': 0,
#   'IgM': 1,
#   'Area': 'Cantonment',
#   'AreaType': 'Developed',
#   'HouseType': 'Building',
#   'District': 'Dhaka',
#   'Outcome': 0},
#  {'Gender': 'Female',
#   'Age': 57,
#   'NS1': 1,
#   'IgG': 1,
#   'IgM': 1,
#   'Area': 'Motijheel',
#   'AreaType': 'Undeveloped',
#   'HouseType': 'Tinshed',
#   'District': 'Dhaka',
#   'Outcome': 1},
#  {'Gender': 'Male',
#   'Age': 17,
#   'NS1': 0,
#   'IgG': 0,
#   'IgM': 0,
#   'Area': 'Mohammadpur',
#   'AreaType': 'Developed',
#   'HouseType': 'Other',
#   'District': 'Dhaka',
#   'Outcome': 0},
#  {'Gender': 'Female',
#   'Age': 56,
#   'NS1': 0,
#   'IgG': 0,
#   'IgM': 0,
#   'Area': 'Kadamtali',
#   'AreaType': 'Undeveloped',
#   'HouseType': 'Tinshed',
#   'District': 'Dhaka',
#   'Outcome': 0},
#  {'Gender': 'Male',
#   'Age': 54,
#   'NS1': 0,
#   'IgG': 0,
#   'IgM': 0,
#   'Area': 'Ramna',
#   'AreaType': 'Developed',
#   'HouseType': 'Other',
#   'District': 'Dhaka',
#   'Outcome': 0},
#  {'Gender': 'Female',
#   'Age': 22,
#   'NS1': 0,
#   'IgG': 0,
#   'IgM': 1,
#   'Area': 'Sutrapur',
#   'AreaType': 'Undeveloped',
#   'HouseType': 'Other',
#   'District': 'Dhaka',
#   'Outcome': 0},
#  {'Gender': 'Female',
#   'Age': 63,
#   'NS1': 1,
#   'IgG': 1,
#   'IgM': 1,
#   'Area': 'Demra',
#   'AreaType': 'Developed',
#   'HouseType': 'Other',
#   'District': 'Dhaka',
#   'Outcome': 1},
#  {'Gender': 'Male',
#   'Age': 54,
#   'NS1': 0,
#   'IgG': 0,
#   'IgM': 1,
#   'Area': 'Mirpur',
#   'AreaType': 'Undeveloped',
#   'HouseType': 'Tinshed',
#   'District': 'Dhaka',
#   'Outcome': 0},
#  {'Gender': 'Male',
#   'Age': 61,
#   'NS1': 1,
#   'IgG': 1,
#   'IgM': 1,
#   'Area': 'Biman Bandar',
#   'AreaType': 'Developed',
#   'HouseType': 'Tinshed',
#   'District': 'Dhaka',
#   'Outcome': 1},
#  {'Gender': 'Female',
#   'Age': 47,
#   'NS1': 1,
#   'IgG': 1,
#   'IgM': 1,
#   'Area': 'Jatrabari',
#   'AreaType': 'Undeveloped',
#   'HouseType': 'Tinshed',
#   'District': 'Dhaka',
#   'Outcome': 1},
#  {'Gender': 'Male',
#   'Age': 18,
#   'NS1': 0,
#   'IgG': 0,
#   'IgM': 1,
#   'Area': 'Motijheel',
#   'AreaType': 'Developed',
#   'HouseType': 'Other',
#   'District': 'Dhaka',
#   'Outcome': 0},
#  {'Gender': 'Female',
#   'Age': 24,
#   'NS1': 1,
#   'IgG': 1,
#   'IgM': 0,
#   'Area': 'Bangshal',
#   'AreaType': 'Undeveloped',
#   'HouseType': 'Other',
#   'District': 'Dhaka',
#   'Outcome': 1},
#  {'Gender': 'Female',
#   'Age': 60,
#   'NS1': 0,
#   'IgG': 0,
#   'IgM': 1,
#   'Area': 'Sabujbagh',
#   'AreaType': 'Developed',
#   'HouseType': 'Other',
#   'District': 'Dhaka',
#   'Outcome': 0},
#  {'Gender': 'Female',
#   'Age': 47,
#   'NS1': 1,
#   'IgG': 1,
#   'IgM': 1,
#   'Area': 'Kalabagan',
#   'AreaType': 'Undeveloped',
#   'HouseType': 'Other',
#   'District': 'Dhaka',
#   'Outcome': 1},
#  {'Gender': 'Female',
#   'Age': 19,
#   'NS1': 1,
#   'IgG': 1,
#   'IgM': 0,
#   'Area': 'Paltan',
#   'AreaType': 'Developed',
#   'HouseType': 'Building',
#   'District': 'Dhaka',
#   'Outcome': 1},
#  {'Gender': 'Male',
#   'Age': 55,
#   'NS1': 1,
#   'IgG': 1,
#   'IgM': 0,
#   'Area': 'Adabor',
#   'AreaType': 'Undeveloped',
#   'HouseType': 'Tinshed',
#   'District': 'Dhaka',
#   'Outcome': 1},
#  {'Gender': 'Female',
#   'Age': 49,
#   'NS1': 1,
#   'IgG': 1,
#   'IgM': 0,
#   'Area': 'Paltan',
#   'AreaType': 'Developed',
#   'HouseType': 'Building',
#   'District': 'Dhaka',
#   'Outcome': 1},
#  {'Gender': 'Male',
#   'Age': 32,
#   'NS1': 0,
#   'IgG': 1,
#   'IgM': 0,
#   'Area': 'Khilgaon',
#   'AreaType': 'Undeveloped',
#   'HouseType': 'Tinshed',
#   'District': 'Dhaka',
#   'Outcome': 1},
#  {'Gender': 'Female',
#   'Age': 8,
#   'NS1': 1,
#   'IgG': 1,
#   'IgM': 0,
#   'Area': 'Demra',
#   'AreaType': 'Developed',
#   'HouseType': 'Tinshed',
#   'District': 'Dhaka',
#   'Outcome': 1},
#  {'Gender': 'Female',
#   'Age': 14,
#   'NS1': 0,
#   'IgG': 0,
#   'IgM': 0,
#   'Area': 'Keraniganj',
#   'AreaType': 'Undeveloped',
#   'HouseType': 'Tinshed',
#   'District': 'Dhaka',
#   'Outcome': 0},
#  {'Gender': 'Male',
#   'Age': 28,
#   'NS1': 0,
#   'IgG': 0,
#   'IgM': 1,
#   'Area': 'Cantonment',
#   'AreaType': 'Developed',
#   'HouseType': 'Other',
#   'District': 'Dhaka',
#   'Outcome': 0},
#  {'Gender': 'Female',
#   'Age': 11,
#   'NS1': 1,
#   'IgG': 1,
#   'IgM': 1,
#   'Area': 'Badda',
#   'AreaType': 'Undeveloped',
#   'HouseType': 'Other',
#   'District': 'Dhaka',
#   'Outcome': 1},
#  {'Gender': 'Male',
#   'Age': 29,
#   'NS1': 0,
#   'IgG': 0,
#   'IgM': 0,
#   'Area': 'Khilgaon',
#   'AreaType': 'Developed',
#   'HouseType': 'Building',
#   'District': 'Dhaka',
#   'Outcome': 0},
#  {'Gender': 'Female',
#   'Age': 62,
#   'NS1': 0,
#   'IgG': 0,
#   'IgM': 1,
#   'Area': 'Shahbagh',
#   'AreaType': 'Undeveloped',
#   'HouseType': 'Other',
#   'District': 'Dhaka',
#   'Outcome': 0},
#  {'Gender': 'Female',
#   'Age': 65,
#   'NS1': 1,
#   'IgG': 1,
#   'IgM': 1,
#   'Area': 'Paltan',
#   'AreaType': 'Developed',
#   'HouseType': 'Other',
#   'District': 'Dhaka',
#   'Outcome': 1},
#  {'Gender': 'Female',
#   'Age': 43,
#   'NS1': 1,
#   'IgG': 1,
#   'IgM': 1,
#   'Area': 'Ramna',
#   'AreaType': 'Undeveloped',
#   'HouseType': 'Other',
#   'District': 'Dhaka',
#   'Outcome': 1},
#  {'Gender': 'Female',
#   'Age': 59,
#   'NS1': 1,
#   'IgG': 1,
#   'IgM': 0,
#   'Area': 'Lalbagh',
#   'AreaType': 'Developed',
#   'HouseType': 'Tinshed',
#   'District': 'Dhaka',
#   'Outcome': 1},
#  {'Gender': 'Female',
#   'Age': 29,
#   'NS1': 1,
#   'IgG': 1,
#   'IgM': 1,
#   'Area': 'Chawkbazar',
#   'AreaType': 'Undeveloped',
#   'HouseType': 'Tinshed',
#   'District': 'Dhaka',
#   'Outcome': 1},
#  {'Gender': 'Male',
#   'Age': 17,
#   'NS1': 0,
#   'IgG': 0,
#   'IgM': 0,
#   'Area': 'Khilkhet',
#   'AreaType': 'Developed',
#   'HouseType': 'Building',
#   'District': 'Dhaka',
#   'Outcome': 0},
#  {'Gender': 'Female',
#   'Age': 41,
#   'NS1': 1,
#   'IgG': 1,
#   'IgM': 1,
#   'Area': 'Shahbagh',
#   'AreaType': 'Undeveloped',
#   'HouseType': 'Other',
#   'District': 'Dhaka',
#   'Outcome': 1},
#  {'Gender': 'Female',
#   'Age': 8,
#   'NS1': 1,
#   'IgG': 1,
#   'IgM': 1,
#   'Area': 'Keraniganj',
#   'AreaType': 'Developed',
#   'HouseType': 'Building',
#   'District': 'Dhaka',
#   'Outcome': 1},
#  {'Gender': 'Female',
#   'Age': 29,
#   'NS1': 1,
#   'IgG': 1,
#   'IgM': 0,
#   'Area': 'Kalabagan',
#   'AreaType': 'Undeveloped',
#   'HouseType': 'Tinshed',
#   'District': 'Dhaka',
#   'Outcome': 1},
#  {'Gender': 'Female',
#   'Age': 54,
#   'NS1': 1,
#   'IgG': 1,
#   'IgM': 0,
#   'Area': 'Kadamtali',
#   'AreaType': 'Developed',
#   'HouseType': 'Tinshed',
#   'District': 'Dhaka',
#   'Outcome': 1},
#  {'Gender': 'Female',
#   'Age': 53,
#   'NS1': 0,
#   'IgG': 0,
#   'IgM': 1,
#   'Area': 'Chawkbazar',
#   'AreaType': 'Undeveloped',
#   'HouseType': 'Building',
#   'District': 'Dhaka',
#   'Outcome': 0},
#  {'Gender': 'Male',
#   'Age': 16,
#   'NS1': 1,
#   'IgG': 1,
#   'IgM': 1,
#   'Area': 'Banasree',
#   'AreaType': 'Developed',
#   'HouseType': 'Building',
#   'District': 'Dhaka',
#   'Outcome': 1},
#  {'Gender': 'Male',
#   'Age': 43,
#   'NS1': 0,
#   'IgG': 0,
#   'IgM': 1,
#   'Area': 'Kalabagan',
#   'AreaType': 'Undeveloped',
#   'HouseType': 'Building',
#   'District': 'Dhaka',
#   'Outcome': 0},
#  {'Gender': 'Male',
#   'Age': 54,
#   'NS1': 0,
#   'IgG': 0,
#   'IgM': 0,
#   'Area': 'Biman Bandar',
#   'AreaType': 'Developed',
#   'HouseType': 'Other',
#   'District': 'Dhaka',
#   'Outcome': 0},
#  {'Gender': 'Male',
#   'Age': 41,
#   'NS1': 0,
#   'IgG': 0,
#   'IgM': 0,
#   'Area': 'Bangshal',
#   'AreaType': 'Undeveloped',
#   'HouseType': 'Tinshed',
#   'District': 'Dhaka',
#   'Outcome': 0},
#  {'Gender': 'Male',
#   'Age': 42,
#   'NS1': 0,
#   'IgG': 0,
#   'IgM': 0,
#   'Area': 'Gulshan',
#   'AreaType': 'Developed',
#   'HouseType': 'Other',
#   'District': 'Dhaka',
#   'Outcome': 0},
#  {'Gender': 'Female',
#   'Age': 45,
#   'NS1': 1,
#   'IgG': 1,
#   'IgM': 1,
#   'Area': 'Sher-e-Bangla Nagar',
#   'AreaType': 'Undeveloped',
#   'HouseType': 'Other',
#   'District': 'Dhaka',
#   'Outcome': 1},
#  {'Gender': 'Male',
#   'Age': 13,
#   'NS1': 1,
#   'IgG': 1,
#   'IgM': 1,
#   'Area': 'Kadamtali',
#   'AreaType': 'Developed',
#   'HouseType': 'Other',
#   'District': 'Dhaka',
#   'Outcome': 1},
#  {'Gender': 'Female',
#   'Age': 10,
#   'NS1': 1,
#   'IgG': 1,
#   'IgM': 0,
#   'Area': 'Banasree',
#   'AreaType': 'Undeveloped',
#   'HouseType': 'Building',
#   'District': 'Dhaka',
#   'Outcome': 1},
#  {'Gender': 'Male',
#   'Age': 18,
#   'NS1': 1,
#   'IgG': 1,
#   'IgM': 0,
#   'Area': 'Kalabagan',
#   'AreaType': 'Developed',
#   'HouseType': 'Building',
#   'District': 'Dhaka',
#   'Outcome': 1},
#  {'Gender': 'Female',
#   'Age': 9,
#   'NS1': 1,
#   'IgG': 1,
#   'IgM': 0,
#   'Area': 'Bosila',
#   'AreaType': 'Undeveloped',
#   'HouseType': 'Tinshed',
#   'District': 'Dhaka',
#   'Outcome': 1},
#  {'Gender': 'Female',
#   'Age': 63,
#   'NS1': 0,
#   'IgG': 0,
#   'IgM': 1,
#   'Area': 'Lalbagh',
#   'AreaType': 'Developed',
#   'HouseType': 'Tinshed',
#   'District': 'Dhaka',
#   'Outcome': 0},
#  {'Gender': 'Male',
#   'Age': 36,
#   'NS1': 1,
#   'IgG': 1,
#   'IgM': 0,
#   'Area': 'Dhanmondi',
#   'AreaType': 'Undeveloped',
#   'HouseType': 'Building',
#   'District': 'Dhaka',
#   'Outcome': 1},
#  {'Gender': 'Male',
#   'Age': 15,
#   'NS1': 0,
#   'IgG': 0,
#   'IgM': 1,
#   'Area': 'Bosila',
#   'AreaType': 'Developed',
#   'HouseType': 'Building',
#   'District': 'Dhaka',
#   'Outcome': 0},
#  {'Gender': 'Male',
#   'Age': 30,
#   'NS1': 0,
#   'IgG': 0,
#   'IgM': 0,
#   'Area': 'Paltan',
#   'AreaType': 'Undeveloped',
#   'HouseType': 'Other',
#   'District': 'Dhaka',
#   'Outcome': 0},
#  {'Gender': 'Female',
#   'Age': 40,
#   'NS1': 1,
#   'IgG': 1,
#   'IgM': 0,
#   'Area': 'Adabor',
#   'AreaType': 'Developed',
#   'HouseType': 'Building',
#   'District': 'Dhaka',
#   'Outcome': 1},
#  {'Gender': 'Male',
#   'Age': 45,
#   'NS1': 1,
#   'IgG': 1,
#   'IgM': 0,
#   'Area': 'Paltan',
#   'AreaType': 'Undeveloped',
#   'HouseType': 'Tinshed',
#   'District': 'Dhaka',
#   'Outcome': 1},
#  {'Gender': 'Female',
#   'Age': 14,
#   'NS1': 0,
#   'IgG': 0,
#   'IgM': 1,
#   'Area': 'Kalabagan',
#   'AreaType': 'Developed',
#   'HouseType': 'Other',
#   'District': 'Dhaka',
#   'Outcome': 0},
#  {'Gender': 'Female',
#   'Age': 9,
#   'NS1': 1,
#   'IgG': 1,
#   'IgM': 0,
#   'Area': 'Dhanmondi',
#   'AreaType': 'Undeveloped',
#   'HouseType': 'Tinshed',
#   'District': 'Dhaka',
#   'Outcome': 1},
#  {'Gender': 'Female',
#   'Age': 42,
#   'NS1': 0,
#   'IgG': 0,
#   'IgM': 1,
#   'Area': 'Gulshan',
#   'AreaType': 'Developed',
#   'HouseType': 'Other',
#   'District': 'Dhaka',
#   'Outcome': 0},
#  {'Gender': 'Female',
#   'Age': 17,
#   'NS1': 0,
#   'IgG': 0,
#   'IgM': 0,
#   'Area': 'Sher-e-Bangla Nagar',
#   'AreaType': 'Undeveloped',
#   'HouseType': 'Building',
#   'District': 'Dhaka',
#   'Outcome': 0},
#  {'Gender': 'Female',
#   'Age': 49,
#   'NS1': 0,
#   'IgG': 0,
#   'IgM': 0,
#   'Area': 'Ramna',
#   'AreaType': 'Developed',
#   'HouseType': 'Building',
#   'District': 'Dhaka',
#   'Outcome': 0},
#  {'Gender': 'Male',
#   'Age': 14,
#   'NS1': 0,
#   'IgG': 0,
#   'IgM': 0,
#   'Area': 'Kadamtali',
#   'AreaType': 'Undeveloped',
#   'HouseType': 'Other',
#   'District': 'Dhaka',
#   'Outcome': 0},
#  {'Gender': 'Female',
#   'Age': 41,
#   'NS1': 0,
#   'IgG': 0,
#   'IgM': 0,
#   'Area': 'Kamrangirchar',
#   'AreaType': 'Developed',
#   'HouseType': 'Building',
#   'District': 'Dhaka',
#   'Outcome': 0},
#  {'Gender': 'Female',
#   'Age': 27,
#   'NS1': 1,
#   'IgG': 1,
#   'IgM': 1,
#   'Area': 'Khilgaon',
#   'AreaType': 'Undeveloped',
#   'HouseType': 'Other',
#   'District': 'Dhaka',
#   'Outcome': 1},
#  {'Gender': 'Male',
#   'Age': 38,
#   'NS1': 1,
#   'IgG': 1,
#   'IgM': 0,
#   'Area': 'Kadamtali',
#   'AreaType': 'Developed',
#   'HouseType': 'Building',
#   'District': 'Dhaka',
#   'Outcome': 1},
#  {'Gender': 'Female',
#   'Age': 14,
#   'NS1': 1,
#   'IgG': 1,
#   'IgM': 0,
#   'Area': 'Rampura',
#   'AreaType': 'Undeveloped',
#   'HouseType': 'Other',
#   'District': 'Dhaka',
#   'Outcome': 1},
#  {'Gender': 'Male',
#   'Age': 28,
#   'NS1': 0,
#   'IgG': 0,
#   'IgM': 1,
#   'Area': 'Kadamtali',
#   'AreaType': 'Developed',
#   'HouseType': 'Tinshed',
#   'District': 'Dhaka',
#   'Outcome': 0},
#  {'Gender': 'Male',
#   'Age': 35,
#   'NS1': 1,
#   'IgG': 1,
#   'IgM': 1,
#   'Area': 'Khilgaon',
#   'AreaType': 'Undeveloped',
#   'HouseType': 'Building',
#   'District': 'Dhaka',
#   'Outcome': 1},
#  {'Gender': 'Male',
#   'Age': 59,
#   'NS1': 0,
#   'IgG': 0,
#   'IgM': 1,
#   'Area': 'Khilgaon',
#   'AreaType': 'Developed',
#   'HouseType': 'Building',
#   'District': 'Dhaka',
#   'Outcome': 0},
#  {'Gender': 'Female',
#   'Age': 58,
#   'NS1': 1,
#   'IgG': 1,
#   'IgM': 1,
#   'Area': 'Lalbagh',
#   'AreaType': 'Undeveloped',
#   'HouseType': 'Building',
#   'District': 'Dhaka',
#   'Outcome': 1},
#  {'Gender': 'Male',
#   'Age': 40,
#   'NS1': 0,
#   'IgG': 0,
#   'IgM': 1,
#   'Area': 'Tejgaon',
#   'AreaType': 'Developed',
#   'HouseType': 'Building',
#   'District': 'Dhaka',
#   'Outcome': 0},
#  {'Gender': 'Male',
#   'Age': 25,
#   'NS1': 0,
#   'IgG': 0,
#   'IgM': 1,
#   'Area': 'Paltan',
#   'AreaType': 'Undeveloped',
#   'HouseType': 'Tinshed',
#   'District': 'Dhaka',
#   'Outcome': 0},
#  {'Gender': 'Male',
#   'Age': 63,
#   'NS1': 0,
#   'IgG': 0,
#   'IgM': 1,
#   'Area': 'Sabujbagh',
#   'AreaType': 'Developed',
#   'HouseType': 'Other',
#   'District': 'Dhaka',
#   'Outcome': 0},
#  {'Gender': 'Female',
#   'Age': 48,
#   'NS1': 1,
#   'IgG': 1,
#   'IgM': 0,
#   'Area': 'Sutrapur',
#   'AreaType': 'Undeveloped',
#   'HouseType': 'Building',
#   'District': 'Dhaka',
#   'Outcome': 1},
#  {'Gender': 'Male',
#   'Age': 15,
#   'NS1': 1,
#   'IgG': 1,
#   'IgM': 1,
#   'Area': 'Pallabi',
#   'AreaType': 'Developed',
#   'HouseType': 'Tinshed',
#   'District': 'Dhaka',
#   'Outcome': 1},
#  {'Gender': 'Male',
#   'Age': 60,
#   'NS1': 0,
#   'IgG': 0,
#   'IgM': 1,
#   'Area': 'Khilkhet',
#   'AreaType': 'Undeveloped',
#   'HouseType': 'Other',
#   'District': 'Dhaka',
#   'Outcome': 0},
#  {'Gender': 'Female',
#   'Age': 13,
#   'NS1': 0,
#   'IgG': 0,
#   'IgM': 1,
#   'Area': 'Demra',
#   'AreaType': 'Developed',
#   'HouseType': 'Tinshed',
#   'District': 'Dhaka',
#   'Outcome': 0},
#  {'Gender': 'Female',
#   'Age': 58,
#   'NS1': 0,
#   'IgG': 0,
#   'IgM': 1,
#   'Area': 'Adabor',
#   'AreaType': 'Undeveloped',
#   'HouseType': 'Tinshed',
#   'District': 'Dhaka',
#   'Outcome': 0},
#  {'Gender': 'Male',
#   'Age': 53,
#   'NS1': 1,
#   'IgG': 1,
#   'IgM': 1,
#   'Area': 'Dhanmondi',
#   'AreaType': 'Developed',
#   'HouseType': 'Other',
#   'District': 'Dhaka',
#   'Outcome': 1},
#  {'Gender': 'Male',
#   'Age': 61,
#   'NS1': 1,
#   'IgG': 1,
#   'IgM': 1,
#   'Area': 'Khilkhet',
#   'AreaType': 'Undeveloped',
#   'HouseType': 'Tinshed',
#   'District': 'Dhaka',
#   'Outcome': 1},
#  {'Gender': 'Female',
#   'Age': 44,
#   'NS1': 0,
#   'IgG': 0,
#   'IgM': 1,
#   'Area': 'Khilkhet',
#   'AreaType': 'Developed',
#   'HouseType': 'Other',
#   'District': 'Dhaka',
#   'Outcome': 0},
#  {'Gender': 'Female',
#   'Age': 40,
#   'NS1': 0,
#   'IgG': 0,
#   'IgM': 0,
#   'Area': 'Tejgaon',
#   'AreaType': 'Undeveloped',
#   'HouseType': 'Tinshed',
#   'District': 'Dhaka',
#   'Outcome': 0},
#  {'Gender': 'Male',
#   'Age': 49,
#   'NS1': 0,
#   'IgG': 0,
#   'IgM': 0,
#   'Area': 'Dhanmondi',
#   'AreaType': 'Developed',
#   'HouseType': 'Tinshed',
#   'District': 'Dhaka',
#   'Outcome': 0},
#  {'Gender': 'Male',
#   'Age': 56,
#   'NS1': 1,
#   'IgG': 1,
#   'IgM': 0,
#   'Area': 'Mohammadpur',
#   'AreaType': 'Undeveloped',
#   'HouseType': 'Building',
#   'District': 'Dhaka',
#   'Outcome': 1},
#  {'Gender': 'Female',
#   'Age': 28,
#   'NS1': 0,
#   'IgG': 0,
#   'IgM': 1,
#   'Area': 'Kadamtali',
#   'AreaType': 'Developed',
#   'HouseType': 'Building',
#   'District': 'Dhaka',
#   'Outcome': 0},
#  {'Gender': 'Male',
#   'Age': 40,
#   'NS1': 0,
#   'IgG': 0,
#   'IgM': 0,
#   'Area': 'Gulshan',
#   'AreaType': 'Undeveloped',
#   'HouseType': 'Tinshed',
#   'District': 'Dhaka',
#   'Outcome': 0},
#  {'Gender': 'Male',
#   'Age': 25,
#   'NS1': 1,
#   'IgG': 1,
#   'IgM': 0,
#   'Area': 'Khilgaon',
#   'AreaType': 'Developed',
#   'HouseType': 'Tinshed',
#   'District': 'Dhaka',
#   'Outcome': 1},
#  {'Gender': 'Female',
#   'Age': 52,
#   'NS1': 0,
#   'IgG': 0,
#   'IgM': 0,
#   'Area': 'Paltan',
#   'AreaType': 'Undeveloped',
#   'HouseType': 'Building',
#   'District': 'Dhaka',
#   'Outcome': 0},
#  {'Gender': 'Female',
#   'Age': 60,
#   'NS1': 0,
#   'IgG': 0,
#   'IgM': 0,
#   'Area': 'Demra',
#   'AreaType': 'Developed',
#   'HouseType': 'Other',
#   'District': 'Dhaka',
#   'Outcome': 0},
#  {'Gender': 'Female',
#   'Age': 59,
#   'NS1': 0,
#   'IgG': 0,
#   'IgM': 1,
#   'Area': 'Kalabagan',
#   'AreaType': 'Undeveloped',
#   'HouseType': 'Building',
#   'District': 'Dhaka',
#   'Outcome': 0},
#  {'Gender': 'Female',
#   'Age': 35,
#   'NS1': 1,
#   'IgG': 1,
#   'IgM': 0,
#   'Area': 'Biman Bandar',
#   'AreaType': 'Developed',
#   'HouseType': 'Building',
#   'District': 'Dhaka',
#   'Outcome': 1},
#  {'Gender': 'Female',
#   'Age': 48,
#   'NS1': 1,
#   'IgG': 1,
#   'IgM': 1,
#   'Area': 'Tejgaon',
#   'AreaType': 'Undeveloped',
#   'HouseType': 'Other',
#   'District': 'Dhaka',
#   'Outcome': 1},
#  {'Gender': 'Male',
#   'Age': 31,
#   'NS1': 1,
#   'IgG': 1,
#   'IgM': 1,
#   'Area': 'Paltan',
#   'AreaType': 'Developed',
#   'HouseType': 'Other',
#   'District': 'Dhaka',
#   'Outcome': 1},
#  {'Gender': 'Male',
#   'Age': 33,
#   'NS1': 1,
#   'IgG': 1,
#   'IgM': 0,
#   'Area': 'Hazaribagh',
#   'AreaType': 'Undeveloped',
#   'HouseType': 'Tinshed',
#   'District': 'Dhaka',
#   'Outcome': 1},
#  {'Gender': 'Female',
#   'Age': 39,
#   'NS1': 1,
#   'IgG': 1,
#   'IgM': 1,
#   'Area': 'New Market',
#   'AreaType': 'Developed',
#   'HouseType': 'Building',
#   'District': 'Dhaka',
#   'Outcome': 1},
#  {'Gender': 'Male',
#   'Age': 34,
#   'NS1': 0,
#   'IgG': 0,
#   'IgM': 0,
#   'Area': 'Badda',
#   'AreaType': 'Undeveloped',
#   'HouseType': 'Other',
#   'District': 'Dhaka',
#   'Outcome': 0},
#  {'Gender': 'Female',
#   'Age': 33,
#   'NS1': 1,
#   'IgG': 1,
#   'IgM': 1,
#   'Area': 'Kadamtali',
#   'AreaType': 'Developed',
#   'HouseType': 'Other',
#   'District': 'Dhaka',
#   'Outcome': 1},
#  {'Gender': 'Female',
#   'Age': 18,
#   'NS1': 0,
#   'IgG': 1,
#   'IgM': 1,
#   'Area': 'Kadamtali',
#   'AreaType': 'Undeveloped',
#   'HouseType': 'Tinshed',
#   'District': 'Dhaka',
#   'Outcome': 1},
#  {'Gender': 'Female',
#   'Age': 43,
#   'NS1': 1,
#   'IgG': 1,
#   'IgM': 1,
#   'Area': 'Jatrabari',
#   'AreaType': 'Developed',
#   'HouseType': 'Other',
#   'District': 'Dhaka',
#   'Outcome': 1},
#  {'Gender': 'Male',
#   'Age': 61,
#   'NS1': 0,
#   'IgG': 0,
#   'IgM': 1,
#   'Area': 'Kafrul',
#   'AreaType': 'Undeveloped',
#   'HouseType': 'Building',
#   'District': 'Dhaka',
#   'Outcome': 0},
#  {'Gender': 'Female',
#   'Age': 46,
#   'NS1': 0,
#   'IgG': 0,
#   'IgM': 0,
#   'Area': 'Gendaria',
#   'AreaType': 'Developed',
#   'HouseType': 'Other',
#   'District': 'Dhaka',
#   'Outcome': 0},
#  {'Gender': 'Male',
#   'Age': 59,
#   'NS1': 1,
#   'IgG': 1,
#   'IgM': 1,
#   'Area': 'Shyampur',
#   'AreaType': 'Undeveloped',
#   'HouseType': 'Other',
#   'District': 'Dhaka',
#   'Outcome': 1},
#  {'Gender': 'Female',
#   'Age': 55,
#   'NS1': 1,
#   'IgG': 1,
#   'IgM': 1,
#   'Area': 'Shahbagh',
#   'AreaType': 'Developed',
#   'HouseType': 'Building',
#   'District': 'Dhaka',
#   'Outcome': 1},
#  {'Gender': 'Male',
#   'Age': 25,
#   'NS1': 0,
#   'IgG': 0,
#   'IgM': 1,
#   'Area': 'Mirpur',
#   'AreaType': 'Undeveloped',
#   'HouseType': 'Tinshed',
#   'District': 'Dhaka',
#   'Outcome': 0},
#  {'Gender': 'Female',
#   'Age': 53,
#   'NS1': 0,
#   'IgG': 0,
#   'IgM': 1,
#   'Area': 'Jatrabari',
#   'AreaType': 'Developed',
#   'HouseType': 'Tinshed',
#   'District': 'Dhaka',
#   'Outcome': 0},
#  {'Gender': 'Female',
#   'Age': 32,
#   'NS1': 1,
#   'IgG': 1,
#   'IgM': 0,
#   'Area': 'Gulshan',
#   'AreaType': 'Undeveloped',
#   'HouseType': 'Building',
#   'District': 'Dhaka',
#   'Outcome': 1},
#  {'Gender': 'Male',
#   'Age': 40,
#   'NS1': 1,
#   'IgG': 1,
#   'IgM': 1,
#   'Area': 'Demra',
#   'AreaType': 'Developed',
#   'HouseType': 'Other',
#   'District': 'Dhaka',
#   'Outcome': 1},
#  {'Gender': 'Male',
#   'Age': 57,
#   'NS1': 1,
#   'IgG': 1,
#   'IgM': 1,
#   'Area': 'Biman Bandar',
#   'AreaType': 'Undeveloped',
#   'HouseType': 'Building',
#   'District': 'Dhaka',
#   'Outcome': 1},
#  {'Gender': 'Male',
#   'Age': 43,
#   'NS1': 0,
#   'IgG': 0,
#   'IgM': 1,
#   'Area': 'Shyampur',
#   'AreaType': 'Developed',
#   'HouseType': 'Other',
#   'District': 'Dhaka',
#   'Outcome': 0},
#  {'Gender': 'Male',
#   'Age': 43,
#   'NS1': 0,
#   'IgG': 0,
#   'IgM': 1,
#   'Area': 'Hazaribagh',
#   'AreaType': 'Undeveloped',
#   'HouseType': 'Building',
#   'District': 'Dhaka',
#   'Outcome': 0},
#  {'Gender': 'Male',
#   'Age': 57,
#   'NS1': 0,
#   'IgG': 0,
#   'IgM': 0,
#   'Area': 'Banasree',
#   'AreaType': 'Developed',
#   'HouseType': 'Building',
#   'District': 'Dhaka',
#   'Outcome': 0},
#  {'Gender': 'Female',
#   'Age': 55,
#   'NS1': 1,
#   'IgG': 1,
#   'IgM': 1,
#   'Area': 'Chawkbazar',
#   'AreaType': 'Undeveloped',
#   'HouseType': 'Other',
#   'District': 'Dhaka',
#   'Outcome': 1},
#  {'Gender': 'Female',
#   'Age': 16,
#   'NS1': 1,
#   'IgG': 1,
#   'IgM': 0,
#   'Area': 'Khilgaon',
#   'AreaType': 'Developed',
#   'HouseType': 'Building',
#   'District': 'Dhaka',
#   'Outcome': 1},
#  {'Gender': 'Male',
#   'Age': 25,
#   'NS1': 0,
#   'IgG': 0,
#   'IgM': 1,
#   'Area': 'Bosila',
#   'AreaType': 'Undeveloped',
#   'HouseType': 'Other',
#   'District': 'Dhaka',
#   'Outcome': 0},
#  {'Gender': 'Female',
#   'Age': 28,
#   'NS1': 1,
#   'IgG': 1,
#   'IgM': 0,
#   'Area': 'Khilgaon',
#   'AreaType': 'Developed',
#   'HouseType': 'Other',
#   'District': 'Dhaka',
#   'Outcome': 1},
#  {'Gender': 'Female',
#   'Age': 41,
#   'NS1': 0,
#   'IgG': 0,
#   'IgM': 0,
#   'Area': 'Rampura',
#   'AreaType': 'Undeveloped',
#   'HouseType': 'Other',
#   'District': 'Dhaka',
#   'Outcome': 0},
#  {'Gender': 'Male',
#   'Age': 52,
#   'NS1': 1,
#   'IgG': 1,
#   'IgM': 1,
#   'Area': 'Bangshal',
#   'AreaType': 'Developed',
#   'HouseType': 'Other',
#   'District': 'Dhaka',
#   'Outcome': 1},
#  {'Gender': 'Male',
#   'Age': 46,
#   'NS1': 1,
#   'IgG': 1,
#   'IgM': 0,
#   'Area': 'Adabor',
#   'AreaType': 'Undeveloped',
#   'HouseType': 'Tinshed',
#   'District': 'Dhaka',
#   'Outcome': 1},
#  {'Gender': 'Female',
#   'Age': 55,
#   'NS1': 0,
#   'IgG': 0,
#   'IgM': 1,
#   'Area': 'Ramna',
#   'AreaType': 'Developed',
#   'HouseType': 'Building',
#   'District': 'Dhaka',
#   'Outcome': 0},
#  {'Gender': 'Female',
#   'Age': 53,
#   'NS1': 1,
#   'IgG': 1,
#   'IgM': 1,
#   'Area': 'Sher-e-Bangla Nagar',
#   'AreaType': 'Undeveloped',
#   'HouseType': 'Tinshed',
#   'District': 'Dhaka',
#   'Outcome': 1},
#  {'Gender': 'Female',
#   'Age': 42,
#   'NS1': 1,
#   'IgG': 1,
#   'IgM': 0,
#   'Area': 'Khilkhet',
#   'AreaType': 'Developed',
#   'HouseType': 'Other',
#   'District': 'Dhaka',
#   'Outcome': 1},
#  {'Gender': 'Female',
#   'Age': 30,
#   'NS1': 0,
#   'IgG': 0,
#   'IgM': 0,
#   'Area': 'Kadamtali',
#   'AreaType': 'Undeveloped',
#   'HouseType': 'Building',
#   'District': 'Dhaka',
#   'Outcome': 0},
#  {'Gender': 'Female',
#   'Age': 18,
#   'NS1': 1,
#   'IgG': 1,
#   'IgM': 0,
#   'Area': 'Kadamtali',
#   'AreaType': 'Developed',
#   'HouseType': 'Tinshed',
#   'District': 'Dhaka',
#   'Outcome': 1},
#  {'Gender': 'Female',
#   'Age': 44,
#   'NS1': 0,
#   'IgG': 0,
#   'IgM': 1,
#   'Area': 'Keraniganj',
#   'AreaType': 'Undeveloped',
#   'HouseType': 'Building',
#   'District': 'Dhaka',
#   'Outcome': 0},
#  {'Gender': 'Female',
#   'Age': 21,
#   'NS1': 1,
#   'IgG': 1,
#   'IgM': 1,
#   'Area': 'Gulshan',
#   'AreaType': 'Developed',
#   'HouseType': 'Tinshed',
#   'District': 'Dhaka',
#   'Outcome': 1},
#  {'Gender': 'Male',
#   'Age': 56,
#   'NS1': 0,
#   'IgG': 0,
#   'IgM': 0,
#   'Area': 'Mohammadpur',
#   'AreaType': 'Undeveloped',
#   'HouseType': 'Building',
#   'District': 'Dhaka',
#   'Outcome': 0},
#  {'Gender': 'Male',
#   'Age': 50,
#   'NS1': 1,
#   'IgG': 1,
#   'IgM': 0,
#   'Area': 'Tejgaon',
#   'AreaType': 'Developed',
#   'HouseType': 'Building',
#   'District': 'Dhaka',
#   'Outcome': 1},
#  {'Gender': 'Female',
#   'Age': 12,
#   'NS1': 1,
#   'IgG': 1,
#   'IgM': 0,
#   'Area': 'Badda',
#   'AreaType': 'Undeveloped',
#   'HouseType': 'Tinshed',
#   'District': 'Dhaka',
#   'Outcome': 1},
#  {'Gender': 'Male',
#   'Age': 43,
#   'NS1': 0,
#   'IgG': 0,
#   'IgM': 0,
#   'Area': 'Dhanmondi',
#   'AreaType': 'Developed',
#   'HouseType': 'Other',
#   'District': 'Dhaka',
#   'Outcome': 0},
#  {'Gender': 'Female',
#   'Age': 42,
#   'NS1': 1,
#   'IgG': 1,
#   'IgM': 0,
#   'Area': 'Mohammadpur',
#   'AreaType': 'Undeveloped',
#   'HouseType': 'Building',
#   'District': 'Dhaka',
#   'Outcome': 1},
#  {'Gender': 'Female',
#   'Age': 38,
#   'NS1': 0,
#   'IgG': 1,
#   'IgM': 0,
#   'Area': 'Jatrabari',
#   'AreaType': 'Developed',
#   'HouseType': 'Other',
#   'District': 'Dhaka',
#   'Outcome': 1},
#  {'Gender': 'Male',
#   'Age': 62,
#   'NS1': 1,
#   'IgG': 1,
#   'IgM': 0,
#   'Area': 'Demra',
#   'AreaType': 'Undeveloped',
#   'HouseType': 'Tinshed',
#   'District': 'Dhaka',
#   'Outcome': 1},
#  {'Gender': 'Female',
#   'Age': 32,
#   'NS1': 0,
#   'IgG': 0,
#   'IgM': 0,
#   'Area': 'Khilkhet',
#   'AreaType': 'Developed',
#   'HouseType': 'Tinshed',
#   'District': 'Dhaka',
#   'Outcome': 0},
#  {'Gender': 'Male',
#   'Age': 19,
#   'NS1': 1,
#   'IgG': 1,
#   'IgM': 0,
#   'Area': 'Kadamtali',
#   'AreaType': 'Undeveloped',
#   'HouseType': 'Building',
#   'District': 'Dhaka',
#   'Outcome': 1},
#  {'Gender': 'Female',
#   'Age': 19,
#   'NS1': 1,
#   'IgG': 1,
#   'IgM': 1,
#   'Area': 'Kafrul',
#   'AreaType': 'Developed',
#   'HouseType': 'Other',
#   'District': 'Dhaka',
#   'Outcome': 1},
#  {'Gender': 'Male',
#   'Age': 40,
#   'NS1': 1,
#   'IgG': 1,
#   'IgM': 1,
#   'Area': 'Sabujbagh',
#   'AreaType': 'Undeveloped',
#   'HouseType': 'Other',
#   'District': 'Dhaka',
#   'Outcome': 1},
#  {'Gender': 'Female',
#   'Age': 10,
#   'NS1': 0,
#   'IgG': 0,
#   'IgM': 1,
#   'Area': 'Mohammadpur',
#   'AreaType': 'Developed',
#   'HouseType': 'Tinshed',
#   'District': 'Dhaka',
#   'Outcome': 0},
#  {'Gender': 'Female',
#   'Age': 20,
#   'NS1': 0,
#   'IgG': 0,
#   'IgM': 0,
#   'Area': 'New Market',
#   'AreaType': 'Undeveloped',
#   'HouseType': 'Tinshed',
#   'District': 'Dhaka',
#   'Outcome': 0},
#  {'Gender': 'Male',
#   'Age': 26,
#   'NS1': 0,
#   'IgG': 0,
#   'IgM': 0,
#   'Area': 'Sher-e-Bangla Nagar',
#   'AreaType': 'Developed',
#   'HouseType': 'Other',
#   'District': 'Dhaka',
#   'Outcome': 0},
#  {'Gender': 'Male',
#   'Age': 29,
#   'NS1': 0,
#   'IgG': 0,
#   'IgM': 0,
#   'Area': 'Hazaribagh',
#   'AreaType': 'Undeveloped',
#   'HouseType': 'Tinshed',
#   'District': 'Dhaka',
#   'Outcome': 0},
#  {'Gender': 'Male',
#   'Age': 39,
#   'NS1': 1,
#   'IgG': 1,
#   'IgM': 1,
#   'Area': 'Shahbagh',
#   'AreaType': 'Developed',
#   'HouseType': 'Other',
#   'District': 'Dhaka',
#   'Outcome': 1},
#  {'Gender': 'Female',
#   'Age': 65,
#   'NS1': 1,
#   'IgG': 1,
#   'IgM': 1,
#   'Area': 'Sutrapur',
#   'AreaType': 'Undeveloped',
#   'HouseType': 'Other',
#   'District': 'Dhaka',
#   'Outcome': 1},
#  {'Gender': 'Female',
#   'Age': 38,
#   'NS1': 0,
#   'IgG': 0,
#   'IgM': 1,
#   'Area': 'Khilkhet',
#   'AreaType': 'Developed',
#   'HouseType': 'Other',
#   'District': 'Dhaka',
#   'Outcome': 0},
#  {'Gender': 'Male',
#   'Age': 14,
#   'NS1': 0,
# ...
#   'NS1': 0,
#   'IgG': 0,
#   'IgM': 1,
#   'Area': 'Banasree',
#   'AreaType': 'Undeveloped',
#   'HouseType': 'Other',
#   'District': 'Dhaka',
#   'Outcome': 0},
#  {'Gender': 'Female',
#   'Age': 42,
#   'NS1': 0,
#   'IgG': 0,
#   'IgM': 0,
#   'Area': 'Mirpur',
#   'AreaType': 'Developed',
#   'HouseType': 'Tinshed',
#   'District': 'Dhaka',
#   'Outcome': 0},
#  {'Gender': 'Male',
#   'Age': 30,
#   'NS1': 1,
#   'IgG': 1,
#   'IgM': 1,
#   'Area': 'Demra',
#   'AreaType': 'Undeveloped',
#   'HouseType': 'Building',
#   'District': 'Dhaka',
#   'Outcome': 1},
#  {'Gender': 'Male',
#   'Age': 33,
#   'NS1': 0,
#   'IgG': 0,
#   'IgM': 0,
#   'Area': 'Hazaribagh',
#   'AreaType': 'Developed',
#   'HouseType': 'Tinshed',
#   'District': 'Dhaka',
#   'Outcome': 0},
#  {'Gender': 'Female',
#   'Age': 61,
#   'NS1': 1,
#   'IgG': 1,
#   'IgM': 1,
#   'Area': 'Biman Bandar',
#   'AreaType': 'Undeveloped',
#   'HouseType': 'Building',
#   'District': 'Dhaka',
#   'Outcome': 1},
#  {'Gender': 'Female',
#   'Age': 47,
#   'NS1': 1,
#   'IgG': 1,
#   'IgM': 1,
#   'Area': 'New Market',
#   'AreaType': 'Developed',
#   'HouseType': 'Building',
#   'District': 'Dhaka',
#   'Outcome': 1},
#  {'Gender': 'Female',
#   'Age': 52,
#   'NS1': 0,
#   'IgG': 0,
#   'IgM': 1,
#   'Area': 'Keraniganj',
#   'AreaType': 'Undeveloped',
#   'HouseType': 'Other',
#   'District': 'Dhaka',
#   'Outcome': 0},
#  {'Gender': 'Male',
#   'Age': 59,
#   'NS1': 0,
#   'IgG': 0,
#   'IgM': 1,
#   'Area': 'Khilgaon',
#   'AreaType': 'Developed',
#   'HouseType': 'Building',
#   'District': 'Dhaka',
#   'Outcome': 0},
#  {'Gender': 'Female',
#   'Age': 29,
#   'NS1': 0,
#   'IgG': 0,
#   'IgM': 0,
#   'Area': 'Banasree',
#   'AreaType': 'Undeveloped',
#   'HouseType': 'Building',
#   'District': 'Dhaka',
#   'Outcome': 0},
#  {'Gender': 'Female',
#   'Age': 50,
#   'NS1': 1,
#   'IgG': 1,
#   'IgM': 1,
#   'Area': 'Bangshal',
#   'AreaType': 'Developed',
#   'HouseType': 'Tinshed',
#   'District': 'Dhaka',
#   'Outcome': 1},
#  {'Gender': 'Female',
#   'Age': 56,
#   'NS1': 1,
#   'IgG': 1,
#   'IgM': 0,
#   'Area': 'Banasree',
#   'AreaType': 'Undeveloped',
#   'HouseType': 'Building',
#   'District': 'Dhaka',
#   'Outcome': 1},
#  {'Gender': 'Male',
#   'Age': 55,
#   'NS1': 1,
#   'IgG': 1,
#   'IgM': 0,
#   'Area': 'Sutrapur',
#   'AreaType': 'Developed',
#   'HouseType': 'Building',
#   'District': 'Dhaka',
#   'Outcome': 1},
#  {'Gender': 'Female',
#   'Age': 44,
#   'NS1': 1,
#   'IgG': 1,
#   'IgM': 1,
#   'Area': 'Adabor',
#   'AreaType': 'Undeveloped',
#   'HouseType': 'Building',
#   'District': 'Dhaka',
#   'Outcome': 1},
#  {'Gender': 'Male',
#   'Age': 37,
#   'NS1': 0,
#   'IgG': 0,
#   'IgM': 0,
#   'Area': 'Adabor',
#   'AreaType': 'Developed',
#   'HouseType': 'Tinshed',
#   'District': 'Dhaka',
#   'Outcome': 0},
#  {'Gender': 'Female',
#   'Age': 42,
#   'NS1': 0,
#   'IgG': 0,
#   'IgM': 1,
#   'Area': 'Banasree',
#   'AreaType': 'Undeveloped',
#   'HouseType': 'Tinshed',
#   'District': 'Dhaka',
#   'Outcome': 0},
#  {'Gender': 'Male',
#   'Age': 8,
#   'NS1': 0,
#   'IgG': 0,
#   'IgM': 1,
#   'Area': 'New Market',
#   'AreaType': 'Developed',
#   'HouseType': 'Building',
#   'District': 'Dhaka',
#   'Outcome': 0},
#  {'Gender': 'Male',
#   'Age': 40,
#   'NS1': 0,
#   'IgG': 0,
#   'IgM': 0,
#   'Area': 'Kamrangirchar',
#   'AreaType': 'Undeveloped',
#   'HouseType': 'Tinshed',
#   'District': 'Dhaka',
#   'Outcome': 0},
#  {'Gender': 'Male',
#   'Age': 56,
#   'NS1': 0,
#   'IgG': 0,
#   'IgM': 1,
#   'Area': 'Dhanmondi',
#   'AreaType': 'Developed',
#   'HouseType': 'Tinshed',
#   'District': 'Dhaka',
#   'Outcome': 0},
#  {'Gender': 'Male',
#   'Age': 60,
#   'NS1': 0,
#   'IgG': 0,
#   'IgM': 1,
#   'Area': 'Jatrabari',
#   'AreaType': 'Undeveloped',
#   'HouseType': 'Building',
#   'District': 'Dhaka',
#   'Outcome': 0},
#  {'Gender': 'Male',
#   'Age': 26,
#   'NS1': 0,
#   'IgG': 0,
#   'IgM': 0,
#   'Area': 'Motijheel',
#   'AreaType': 'Developed',
#   'HouseType': 'Tinshed',
#   'District': 'Dhaka',
#   'Outcome': 0},
#  {'Gender': 'Female',
#   'Age': 65,
#   'NS1': 1,
#   'IgG': 1,
#   'IgM': 0,
#   'Area': 'Mohammadpur',
#   'AreaType': 'Undeveloped',
#   'HouseType': 'Building',
#   'District': 'Dhaka',
#   'Outcome': 1},
#  {'Gender': 'Female',
#   'Age': 33,
#   'NS1': 1,
#   'IgG': 1,
#   'IgM': 1,
#   'Area': 'Tejgaon',
#   'AreaType': 'Developed',
#   'HouseType': 'Building',
#   'District': 'Dhaka',
#   'Outcome': 1},
#  {'Gender': 'Female',
#   'Age': 20,
#   'NS1': 0,
#   'IgG': 0,
#   'IgM': 0,
#   'Area': 'Rampura',
#   'AreaType': 'Undeveloped',
#   'HouseType': 'Other',
#   'District': 'Dhaka',
#   'Outcome': 0},
#  {'Gender': 'Male',
#   'Age': 20,
#   'NS1': 0,
#   'IgG': 0,
#   'IgM': 0,
#   'Area': 'Cantonment',
#   'AreaType': 'Developed',
#   'HouseType': 'Other',
#   'District': 'Dhaka',
#   'Outcome': 0},
#  {'Gender': 'Female',
#   'Age': 54,
#   'NS1': 1,
#   'IgG': 1,
#   'IgM': 0,
#   'Area': 'Kadamtali',
#   'AreaType': 'Undeveloped',
#   'HouseType': 'Building',
#   'District': 'Dhaka',
#   'Outcome': 1},
#  {'Gender': 'Male',
#   'Age': 22,
#   'NS1': 1,
#   'IgG': 1,
#   'IgM': 1,
#   'Area': 'Banasree',
#   'AreaType': 'Developed',
#   'HouseType': 'Tinshed',
#   'District': 'Dhaka',
#   'Outcome': 1},
#  {'Gender': 'Female',
#   'Age': 16,
#   'NS1': 0,
#   'IgG': 0,
#   'IgM': 0,
#   'Area': 'Paltan',
#   'AreaType': 'Undeveloped',
#   'HouseType': 'Tinshed',
#   'District': 'Dhaka',
#   'Outcome': 0},
#  {'Gender': 'Female',
#   'Age': 37,
#   'NS1': 0,
#   'IgG': 0,
#   'IgM': 0,
#   'Area': 'Rampura',
#   'AreaType': 'Developed',
#   'HouseType': 'Building',
#   'District': 'Dhaka',
#   'Outcome': 0},
#  {'Gender': 'Female',
#   'Age': 26,
#   'NS1': 0,
#   'IgG': 0,
#   'IgM': 1,
#   'Area': 'Demra',
#   'AreaType': 'Undeveloped',
#   'HouseType': 'Tinshed',
#   'District': 'Dhaka',
#   'Outcome': 0},
#  {'Gender': 'Female',
#   'Age': 27,
#   'NS1': 0,
#   'IgG': 0,
#   'IgM': 0,
#   'Area': 'Hazaribagh',
#   'AreaType': 'Developed',
#   'HouseType': 'Tinshed',
#   'District': 'Dhaka',
#   'Outcome': 0},
#  {'Gender': 'Female',
#   'Age': 10,
#   'NS1': 0,
#   'IgG': 0,
#   'IgM': 0,
#   'Area': 'Kadamtali',
#   'AreaType': 'Undeveloped',
#   'HouseType': 'Building',
#   'District': 'Dhaka',
#   'Outcome': 0},
#  {'Gender': 'Female',
#   'Age': 15,
#   'NS1': 0,
#   'IgG': 0,
#   'IgM': 0,
#   'Area': 'Ramna',
#   'AreaType': 'Developed',
#   'HouseType': 'Building',
#   'District': 'Dhaka',
#   'Outcome': 0},
#  {'Gender': 'Female',
#   'Age': 17,
#   'NS1': 0,
#   'IgG': 0,
#   'IgM': 0,
#   'Area': 'Biman Bandar',
#   'AreaType': 'Undeveloped',
#   'HouseType': 'Tinshed',
#   'District': 'Dhaka',
#   'Outcome': 0},
#  {'Gender': 'Female',
#   'Age': 61,
#   'NS1': 1,
#   'IgG': 1,
#   'IgM': 1,
#   'Area': 'Mirpur',
#   'AreaType': 'Developed',
#   'HouseType': 'Building',
#   'District': 'Dhaka',
#   'Outcome': 1},
#  {'Gender': 'Male',
#   'Age': 35,
#   'NS1': 1,
#   'IgG': 1,
#   'IgM': 1,
#   'Area': 'Shahbagh',
#   'AreaType': 'Undeveloped',
#   'HouseType': 'Other',
#   'District': 'Dhaka',
#   'Outcome': 1},
#  {'Gender': 'Female',
#   'Age': 55,
#   'NS1': 1,
#   'IgG': 1,
#   'IgM': 1,
#   'Area': 'Rampura',
#   'AreaType': 'Developed',
#   'HouseType': 'Other',
#   'District': 'Dhaka',
#   'Outcome': 1},
#  {'Gender': 'Female',
#   'Age': 16,
#   'NS1': 1,
#   'IgG': 1,
#   'IgM': 1,
#   'Area': 'Lalbagh',
#   'AreaType': 'Undeveloped',
#   'HouseType': 'Other',
#   'District': 'Dhaka',
#   'Outcome': 1},
#  {'Gender': 'Male',
#   'Age': 52,
#   'NS1': 0,
#   'IgG': 0,
#   'IgM': 0,
#   'Area': 'Kadamtali',
#   'AreaType': 'Developed',
#   'HouseType': 'Building',
#   'District': 'Dhaka',
#   'Outcome': 0},
#  {'Gender': 'Female',
#   'Age': 50,
#   'NS1': 0,
#   'IgG': 0,
#   'IgM': 0,
#   'Area': 'Motijheel',
#   'AreaType': 'Undeveloped',
#   'HouseType': 'Other',
#   'District': 'Dhaka',
#   'Outcome': 0},
#  {'Gender': 'Female',
#   'Age': 23,
#   'NS1': 1,
#   'IgG': 1,
#   'IgM': 1,
#   'Area': 'Kafrul',
#   'AreaType': 'Developed',
#   'HouseType': 'Tinshed',
#   'District': 'Dhaka',
#   'Outcome': 1},
#  {'Gender': 'Male',
#   'Age': 64,
#   'NS1': 1,
#   'IgG': 1,
#   'IgM': 0,
#   'Area': 'Demra',
#   'AreaType': 'Undeveloped',
#   'HouseType': 'Building',
#   'District': 'Dhaka',
#   'Outcome': 1},
#  {'Gender': 'Female',
#   'Age': 50,
#   'NS1': 0,
#   'IgG': 0,
#   'IgM': 0,
#   'Area': 'Rampura',
#   'AreaType': 'Developed',
#   'HouseType': 'Tinshed',
#   'District': 'Dhaka',
#   'Outcome': 0},
#  {'Gender': 'Female',
#   'Age': 8,
#   'NS1': 0,
#   'IgG': 1,
#   'IgM': 0,
#   'Area': 'Cantonment',
#   'AreaType': 'Developed',
#   'HouseType': 'Other',
#   'District': 'Dhaka',
#   'Outcome': 1},
#  {'Gender': 'Female',
#   'Age': 37,
#   'NS1': 0,
#   'IgG': 0,
#   'IgM': 1,
#   'Area': 'Shyampur',
#   'AreaType': 'Developed',
#   'HouseType': 'Tinshed',
#   'District': 'Dhaka',
#   'Outcome': 0},
#  {'Gender': 'Female',
#   'Age': 63,
#   'NS1': 0,
#   'IgG': 0,
#   'IgM': 0,
#   'Area': 'Rampura',
#   'AreaType': 'Undeveloped',
#   'HouseType': 'Other',
#   'District': 'Dhaka',
#   'Outcome': 0},
#  {'Gender': 'Female',
#   'Age': 45,
#   'NS1': 0,
#   'IgG': 0,
#   'IgM': 0,
#   'Area': 'Biman Bandar',
#   'AreaType': 'Developed',
#   'HouseType': 'Other',
#   'District': 'Dhaka',
#   'Outcome': 0},
#  {'Gender': 'Female',
#   'Age': 26,
#   'NS1': 0,
#   'IgG': 0,
#   'IgM': 0,
#   'Area': 'Khilgaon',
#   'AreaType': 'Undeveloped',
#   'HouseType': 'Building',
#   'District': 'Dhaka',
#   'Outcome': 0},
#  {'Gender': 'Female',
#   'Age': 24,
#   'NS1': 0,
#   'IgG': 0,
#   'IgM': 0,
#   'Area': 'Banasree',
#   'AreaType': 'Developed',
#   'HouseType': 'Other',
#   'District': 'Dhaka',
#   'Outcome': 0},
#  {'Gender': 'Male',
#   'Age': 31,
#   'NS1': 1,
#   'IgG': 1,
#   'IgM': 0,
#   'Area': 'Keraniganj',
#   'AreaType': 'Undeveloped',
#   'HouseType': 'Tinshed',
#   'District': 'Dhaka',
#   'Outcome': 1},
#  {'Gender': 'Female',
#   'Age': 54,
#   'NS1': 0,
#   'IgG': 0,
#   'IgM': 1,
#   'Area': 'Sher-e-Bangla Nagar',
#   'AreaType': 'Developed',
#   'HouseType': 'Tinshed',
#   'District': 'Dhaka',
#   'Outcome': 0},
#  {'Gender': 'Male',
#   'Age': 60,
#   'NS1': 1,
#   'IgG': 1,
#   'IgM': 1,
#   'Area': 'Kamrangirchar',
#   'AreaType': 'Undeveloped',
#   'HouseType': 'Building',
#   'District': 'Dhaka',
#   'Outcome': 1},
#  {'Gender': 'Male',
#   'Age': 61,
#   'NS1': 1,
#   'IgG': 1,
#   'IgM': 1,
#   'Area': 'Gendaria',
#   'AreaType': 'Developed',
#   'HouseType': 'Building',
#   'District': 'Dhaka',
#   'Outcome': 1},
#  {'Gender': 'Male',
#   'Age': 58,
#   'NS1': 0,
#   'IgG': 1,
#   'IgM': 0,
#   'Area': 'Sabujbagh',
#   'AreaType': 'Undeveloped',
#   'HouseType': 'Tinshed',
#   'District': 'Dhaka',
#   'Outcome': 1},
#  {'Gender': 'Female',
#   'Age': 39,
#   'NS1': 0,
#   'IgG': 0,
#   'IgM': 1,
#   'Area': 'Sutrapur',
#   'AreaType': 'Developed',
#   'HouseType': 'Tinshed',
#   'District': 'Dhaka',
#   'Outcome': 0},
#  {'Gender': 'Female',
#   'Age': 30,
#   'NS1': 0,
#   'IgG': 0,
#   'IgM': 1,
#   'Area': 'Lalbagh',
#   'AreaType': 'Undeveloped',
#   'HouseType': 'Other',
#   'District': 'Dhaka',
#   'Outcome': 0},
#  {'Gender': 'Male',
#   'Age': 57,
#   'NS1': 1,
#   'IgG': 1,
#   'IgM': 0,
#   'Area': 'Badda',
#   'AreaType': 'Developed',
#   'HouseType': 'Other',
#   'District': 'Dhaka',
#   'Outcome': 1},
#  {'Gender': 'Female',
#   'Age': 40,
#   'NS1': 1,
#   'IgG': 1,
#   'IgM': 0,
#   'Area': 'Paltan',
#   'AreaType': 'Undeveloped',
#   'HouseType': 'Tinshed',
#   'District': 'Dhaka',
#   'Outcome': 1},
#  {'Gender': 'Male',
#   'Age': 39,
#   'NS1': 0,
#   'IgG': 0,
#   'IgM': 0,
#   'Area': 'Gulshan',
#   'AreaType': 'Developed',
#   'HouseType': 'Building',
#   'District': 'Dhaka',
#   'Outcome': 0},
#  {'Gender': 'Female',
#   'Age': 9,
#   'NS1': 1,
#   'IgG': 1,
#   'IgM': 1,
#   'Area': 'Gulshan',
#   'AreaType': 'Undeveloped',
#   'HouseType': 'Other',
#   'District': 'Dhaka',
#   'Outcome': 1},
#  {'Gender': 'Male',
#   'Age': 26,
#   'NS1': 0,
#   'IgG': 1,
#   'IgM': 0,
#   'Area': 'Kamrangirchar',
#   'AreaType': 'Developed',
#   'HouseType': 'Other',
#   'District': 'Dhaka',
#   'Outcome': 1},
#  {'Gender': 'Female',
#   'Age': 40,
#   'NS1': 1,
#   'IgG': 1,
#   'IgM': 0,
#   'Area': 'Tejgaon',
#   'AreaType': 'Undeveloped',
#   'HouseType': 'Building',
#   'District': 'Dhaka',
#   'Outcome': 1},
#  {'Gender': 'Male',
#   'Age': 49,
#   'NS1': 1,
#   'IgG': 1,
#   'IgM': 1,
#   'Area': 'New Market',
#   'AreaType': 'Developed',
#   'HouseType': 'Other',
#   'District': 'Dhaka',
#   'Outcome': 1},
#  {'Gender': 'Female',
#   'Age': 29,
#   'NS1': 0,
#   'IgG': 0,
#   'IgM': 1,
#   'Area': 'Jatrabari',
#   'AreaType': 'Undeveloped',
#   'HouseType': 'Tinshed',
#   'District': 'Dhaka',
#   'Outcome': 0},
#  {'Gender': 'Female',
#   'Age': 38,
#   'NS1': 1,
#   'IgG': 1,
#   'IgM': 0,
#   'Area': 'Banasree',
#   'AreaType': 'Developed',
#   'HouseType': 'Other',
#   'District': 'Dhaka',
#   'Outcome': 1},
#  {'Gender': 'Male',
#   'Age': 52,
#   'NS1': 0,
#   'IgG': 0,
#   'IgM': 1,
#   'Area': 'Chawkbazar',
#   'AreaType': 'Undeveloped',
#   'HouseType': 'Building',
#   'District': 'Dhaka',
#   'Outcome': 0},
#  {'Gender': 'Male',
#   'Age': 64,
#   'NS1': 0,
#   'IgG': 0,
#   'IgM': 0,
#   'Area': 'Hazaribagh',
#   'AreaType': 'Developed',
#   'HouseType': 'Building',
#   'District': 'Dhaka',
#   'Outcome': 0},
#  {'Gender': 'Male',
#   'Age': 11,
#   'NS1': 0,
#   'IgG': 0,
#   'IgM': 0,
#   'Area': 'Banasree',
#   'AreaType': 'Undeveloped',
#   'HouseType': 'Other',
#   'District': 'Dhaka',
#   'Outcome': 0},
#  {'Gender': 'Male',
#   'Age': 39,
#   'NS1': 1,
#   'IgG': 1,
#   'IgM': 0,
#   'Area': 'Jatrabari',
#   'AreaType': 'Developed',
#   'HouseType': 'Other',
#   'District': 'Dhaka',
#   'Outcome': 1},
#  {'Gender': 'Male',
#   'Age': 39,
#   'NS1': 1,
#   'IgG': 1,
#   'IgM': 0,
#   'Area': 'Biman Bandar',
#   'AreaType': 'Undeveloped',
#   'HouseType': 'Tinshed',
#   'District': 'Dhaka',
#   'Outcome': 1},
#  {'Gender': 'Female',
#   'Age': 25,
#   'NS1': 1,
#   'IgG': 1,
#   'IgM': 0,
#   'Area': 'Rampura',
#   'AreaType': 'Developed',
#   'HouseType': 'Tinshed',
#   'District': 'Dhaka',
#   'Outcome': 1},
#  {'Gender': 'Male',
#   'Age': 9,
#   'NS1': 0,
#   'IgG': 0,
#   'IgM': 1,
#   'Area': 'Mirpur',
#   'AreaType': 'Undeveloped',
#   'HouseType': 'Building',
#   'District': 'Dhaka',
#   'Outcome': 0},
#  {'Gender': 'Female',
#   'Age': 61,
#   'NS1': 1,
#   'IgG': 1,
#   'IgM': 0,
#   'Area': 'Gendaria',
#   'AreaType': 'Developed',
#   'HouseType': 'Building',
#   'District': 'Dhaka',
#   'Outcome': 1},
#  {'Gender': 'Female',
#   'Age': 18,
#   'NS1': 0,
#   'IgG': 0,
#   'IgM': 1,
#   'Area': 'Gulshan',
#   'AreaType': 'Undeveloped',
#   'HouseType': 'Building',
#   'District': 'Dhaka',
#   'Outcome': 0},
#  {'Gender': 'Female',
#   'Age': 55,
#   'NS1': 1,
#   'IgG': 1,
#   'IgM': 0,
#   'Area': 'Cantonment',
#   'AreaType': 'Developed',
#   'HouseType': 'Tinshed',
#   'District': 'Dhaka',
#   'Outcome': 1},
#  {'Gender': 'Male',
#   'Age': 11,
#   'NS1': 0,
#   'IgG': 0,
#   'IgM': 0,
#   'Area': 'Banasree',
#   'AreaType': 'Undeveloped',
#   'HouseType': 'Building',
#   'District': 'Dhaka',
#   'Outcome': 0},
#  {'Gender': 'Male',
#   'Age': 23,
#   'NS1': 1,
#   'IgG': 1,
#   'IgM': 0,
#   'Area': 'Lalbagh',
#   'AreaType': 'Developed',
#   'HouseType': 'Building',
#   'District': 'Dhaka',
#   'Outcome': 1},
#  {'Gender': 'Female',
#   'Age': 37,
#   'NS1': 1,
#   'IgG': 1,
#   'IgM': 1,
#   'Area': 'Jatrabari',
#   'AreaType': 'Undeveloped',
#   'HouseType': 'Other',
#   'District': 'Dhaka',
#   'Outcome': 1},
#  {'Gender': 'Female',
#   'Age': 33,
#   'NS1': 0,
#   'IgG': 0,
#   'IgM': 1,
#   'Area': 'Hazaribagh',
#   'AreaType': 'Developed',
#   'HouseType': 'Other',
#   'District': 'Dhaka',
#   'Outcome': 0},
#  {'Gender': 'Male',
#   'Age': 18,
#   'NS1': 1,
#   'IgG': 1,
#   'IgM': 0,
#   'Area': 'Kafrul',
#   'AreaType': 'Undeveloped',
#   'HouseType': 'Building',
#   'District': 'Dhaka',
#   'Outcome': 1},
#  {'Gender': 'Female',
#   'Age': 15,
#   'NS1': 0,
#   'IgG': 0,
#   'IgM': 0,
#   'Area': 'Kadamtali',
#   'AreaType': 'Developed',
#   'HouseType': 'Other',
#   'District': 'Dhaka',
#   'Outcome': 0},
#  {'Gender': 'Male',
#   'Age': 44,
#   'NS1': 0,
#   'IgG': 0,
#   'IgM': 1,
#   'Area': 'Bangshal',
#   'AreaType': 'Undeveloped',
#   'HouseType': 'Other',
#   'District': 'Dhaka',
#   'Outcome': 0},
#  {'Gender': 'Female',
#   'Age': 16,
#   'NS1': 1,
#   'IgG': 1,
#   'IgM': 0,
#   'Area': 'New Market',
#   'AreaType': 'Developed',
#   'HouseType': 'Building',
#   'District': 'Dhaka',
#   'Outcome': 1},
#  {'Gender': 'Male',
#   'Age': 41,
#   'NS1': 1,
#   'IgG': 1,
#   'IgM': 0,
#   'Area': 'Paltan',
#   'AreaType': 'Undeveloped',
#   'HouseType': 'Other',
#   'District': 'Dhaka',
#   'Outcome': 1},
#  {'Gender': 'Male',
#   'Age': 45,
#   'NS1': 0,
#   'IgG': 0,
#   'IgM': 1,
#   'Area': 'Motijheel',
#   'AreaType': 'Developed',
#   'HouseType': 'Building',
#   'District': 'Dhaka',
#   'Outcome': 0},
#  {'Gender': 'Female',
#   'Age': 19,
#   'NS1': 1,
#   'IgG': 1,
#   'IgM': 1,
#   'Area': 'Paltan',
#   'AreaType': 'Undeveloped',
#   'HouseType': 'Building',
#   'District': 'Dhaka',
#   'Outcome': 1},
#  {'Gender': 'Female',
#   'Age': 28,
#   'NS1': 0,
#   'IgG': 0,
#   'IgM': 1,
#   'Area': 'Adabor',
#   'AreaType': 'Developed',
#   'HouseType': 'Building',
#   'District': 'Dhaka',
#   'Outcome': 0}]

# %%
import os
from dotenv import load_dotenv

load_dotenv()  # Load variables from .env

DB_NAME = os.getenv("DB_NAME")
COLLECTION_NAME = os.getenv("COLLECTION_NAME")
CONNECTION_URL = os.getenv("CONNECTION_URL")

# %%
# Connect to MongoDB
from pymongo import MongoClient
client = MongoClient(CONNECTION_URL)
db = client[DB_NAME]
collection = db[COLLECTION_NAME]

# %%
#Insert the data into MongoDB
rec=collection.insert_many(data)

# %%
record=collection.find()

# %%
# Convert the data into pandas DataFrame
df=pd.DataFrame(list(record))

# %%
df.head(5)
# Out:
#                         _id  Gender  Age  NS1  IgG  IgM        Area  \
# 0  68f0c1255661865aafb215e5  Female   45    0    0    0      Mirpur
# 1  68f0c1255661865aafb215e6    Male   17    0    0    1  Chawkbazar
# 2  68f0c1255661865aafb215e7  Female   29    0    0    0      Paltan
# 3  68f0c1255661865aafb215e8  Female   63    1    1    0   Motijheel
# 4  68f0c1255661865aafb215e9    Male   22    0    0    0    Gendaria
#
#       AreaType HouseType District  Outcome
# 0  Undeveloped  Building    Dhaka        0
# 1    Developed  Building    Dhaka        0
# 2  Undeveloped     Other    Dhaka        0
# 3    Developed     Other    Dhaka        1
# 4  Undeveloped  Building    Dhaka        0

# %%
if "_id" in df.columns:
    df.drop(columns=["_id"], inplace=True)

# %%
df.head(5)
# Out:
#    Gender  Age  NS1  IgG  IgM        Area     AreaType HouseType District  \
# 0  Female   45    0    0    0      Mirpur  Undeveloped  Building    Dhaka
# 1    Male   17    0    0    1  Chawkbazar    Developed  Building    Dhaka
# 2  Female   29    0    0    0      Paltan  Undeveloped     Other    Dhaka
# 3  Female   63    1    1    0   Motijheel    Developed     Other    Dhaka
# 4    Male   22    0    0    0    Gendaria  Undeveloped  Building    Dhaka
#
#    Outcome
# 0        0
# 1        0
# 2        0
# 3        1
# 4        0
